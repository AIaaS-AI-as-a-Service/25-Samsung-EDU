# %% [markdown]
# # **이상탐지2: 수업실습용**
#
# 이 노트북은 이상 탐지(Anomaly Detection)의 4가지 고급 방법을 실습하는 자료입니다:
# 1. **Isolation Forest**: 의사결정나무 기반 앙상블 이상 탐지
# 2. **Local Outlier Factor (LOF)**: 밀도 기반 지역적 이상 탐지
# 3. **PCA (Principal Component Analysis)**: 재구축 오차 기반 이상 탐지
# 4. **Auto-Encoder**: 딥러닝 기반 재구축 오차 이상 탐지
#
# 각 방법의 원리와 구현 방법을 학습하고, 결과를 비교 분석합니다.

# %% [markdown]
# ## **1. 라이브러리 로드**
#
# 필요한 라이브러리들을 import합니다:
# - **pandas, numpy**: 데이터 처리 및 수치 연산
# - **sklearn**: 머신러닝 모델 및 평가 지표
# - **pyod**: 이상 탐지 전용 라이브러리 (Isolation Forest, PCA)
# - **tensorflow**: 딥러닝 모델 구축 (Auto-Encoder)
# - **matplotlib, seaborn**: 데이터 시각화

# %%
# pandas: 데이터프레임을 다루기 위한 라이브러리 (데이터 조작 및 분석)
import pandas as pd
# numpy: 수치 연산을 위한 라이브러리 (배열 연산, 수학 함수)
import numpy as np
# warnings: 경고 메시지를 제어하기 위한 모듈
import warnings
# 모든 경고 메시지를 무시하도록 설정 (코드 실행 시 경고가 출력되지 않음)
warnings.filterwarnings(action='ignore') 
# Jupyter 노트북에서 matplotlib 그래프를 인라인으로 표시하도록 설정
# %matplotlib inline

# 데이터 전처리 패키지
# make_blobs: 클러스터링을 위한 가상의 데이터셋을 생성하는 함수
from sklearn.datasets import make_blobs
# PCA: 주성분 분석 (차원 축소 및 재구축 오차 계산용)
from sklearn.decomposition import PCA

# 모델 패키지
# IForest: Isolation Forest 모델 (PYOD 라이브러리)
# Isolation Forest는 의사결정나무 기반 앙상블 이상 탐지 알고리즘
from pyod.models.iforest import IForest
# PCA: PYOD 라이브러리의 PCA 기반 이상 탐지 모델
# 재구축 오차를 이용하여 이상치를 탐지
from pyod.models.pca import PCA
# LocalOutlierFactor: 지역적 이상치 인자 (LOF) 알고리즘
# 밀도 기반으로 지역적 이상치를 탐지하는 방법
from sklearn.neighbors import LocalOutlierFactor
# tensorflow: 딥러닝 프레임워크 (Auto-Encoder 구현에 사용)
import tensorflow as tf

# 모델 평가 패키지
# accuracy_score: 정확도 계산 (전체 중 맞게 예측한 비율)
# f1_score: F1 점수 계산 (정밀도와 재현율의 조화 평균)
# confusion_matrix: 혼동 행렬 생성 (실제값과 예측값의 비교)
# precision_score: 정밀도 계산 (예측한 이상치 중 실제 이상치 비율)
# recall_score: 재현율 계산 (실제 이상치 중 올바르게 탐지한 비율)
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, precision_score, recall_score


# 시각화 패키지
# matplotlib: 기본적인 그래프 그리기 라이브러리
import matplotlib
# pyplot: matplotlib의 그래프 그리기 인터페이스
import matplotlib.pyplot as plt
# seaborn: matplotlib 기반의 고급 시각화 라이브러리 (통계 그래프에 특화)
import seaborn as sns
# seaborn의 스타일을 'white'로 설정 (흰색 배경의 깔끔한 그래프)
sns.set_style('white')

# 마이너스 기호(-) 깨짐 방지
# matplotlib에서 마이너스 기호가 깨지지 않도록 설정 (한글 환경에서 주로 발생하는 문제)
matplotlib.rcParams['axes.unicode_minus'] = False

# # 한글 폰트 사용하기
# # 주석 처리됨: 한글을 그래프에 표시할 때 사용하는 폰트 설정 (필요시 주석 해제)
# plt.rc('font', family='Malgun Gothic')
# Out:
# 2025-11-25 01:27:48.640580: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-25 01:27:48.645837: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-25 01:27:48.660287: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764034068.683604   94056 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764034068.690333   94056 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# ## **2. 이상치 데이터 셋 임의로 생성**

# %% [markdown]
# - make_blobs: 서로 다른 클러스터를 형성하는 데이터를 생성하는 함수
# - 입력 매개변수:
#     - n_samples: 생성할 데이터 포인트의 수.
#     - n_features: 각 데이터 포인트의 특성(차원) 수.
#     - centers: 클러스터의 중심 수 또는 중심의 좌표.
#     - cluster_std: 각 클러스터의 표준 편차로, 클러스터의 분산 정도를 조절합니다.
#     - random_state: 난수 생성 시드로, 동일한 결과를 재현할 수 있도록 합니다.

# %% [markdown]
# **train 데이터셋 생성**
#
# - 정상 데이터: 1000개, 1개의 클러스터 중심, 표준편차 1, 5차원 특성 (밀집된 정상 데이터)
# - 이상 데이터: 100개, 2개의 클러스터 중심, 표준편차 10, 5차원 특성 (분산이 큰 이상 데이터)
# - 이전 노트북과 달리 5차원 데이터를 사용하여 고차원 데이터에서의 이상 탐지 성능을 확인합니다

# %%
# 정상 데이터 생성 (학습 데이터셋용)
# make_blobs: 가상의 클러스터 데이터를 생성
# n_samples=1000: 정상 데이터 1000개 생성
# centers=1: 1개의 클러스터 중심점 (밀집된 정상 데이터)
# n_features=5: 5개의 특성 차원 (고차원 데이터)
# cluster_std=1: 클러스터의 표준편차를 1로 설정 (작은 값이므로 밀집된 클러스터)
# random_state=0: 재현 가능한 결과를 위한 시드값 설정
# center_box=(5,9): 클러스터 중심점의 좌표 범위 (5~9 사이)
X_normal_train, y_normal_train = make_blobs(n_samples=1000, centers=1, n_features=5, cluster_std=1, random_state=0, center_box=(5,9))
# 생성된 정상 데이터를 데이터프레임으로 변환
# columns=['x1', 'x2', 'x3', 'x4', 'x5']: 5개 특성에 이름 부여
df_normal_train = pd.DataFrame(X_normal_train, columns=['x1', 'x2', 'x3', 'x4', 'x5'])
# anomaly_indicator=0: 정상 데이터이므로 이상치 지표를 0으로 설정
df_normal_train['anomaly_indicator']=0

# 이상 데이터 생성 (학습 데이터셋용)
# n_samples=100: 이상 데이터 100개 생성 (정상 데이터보다 적음)
# centers=2: 2개의 클러스터 중심점
# cluster_std=10: 표준편차를 10으로 설정 (큰 값이므로 넓게 퍼진 데이터 = 이상치)
# center_box=(10,12): 클러스터 중심점의 좌표 범위 (10~12 사이, 정상 데이터와 다른 위치)
X_abnormal_train, y_abnormal_train = make_blobs(n_samples=100, centers=2, n_features=5, cluster_std=10, random_state=0, center_box=(10,12))
# 생성된 이상 데이터를 데이터프레임으로 변환
df_abnormal_train = pd.DataFrame(X_abnormal_train, columns=['x1', 'x2', 'x3', 'x4', 'x5'])
# anomaly_indicator=1: 이상 데이터이므로 이상치 지표를 1로 설정
df_abnormal_train['anomaly_indicator']=1
# 이상 데이터, 정상데이터 combine
# pd.concat: 두 데이터프레임을 세로로 결합 (행 결합)
# 최종적으로 정상 1000개 + 이상 100개 = 총 1100개의 학습 데이터 생성
df_train = pd.concat([df_normal_train, df_abnormal_train])

# %% [markdown]
# **test 데이터셋 생성**
#
# - 정상 데이터: 200개 (train의 1/5 크기)
# - 이상 데이터: 20개 (train의 1/5 크기)
# - train과 동일한 파라미터로 생성하여 일관성 유지

# %%
# 정상 데이터 생성 (테스트 데이터셋용)
# n_samples=200: 테스트용 정상 데이터 200개 생성 (학습 데이터의 1/5 크기)
# centers=1: 1개의 클러스터 중심점 (학습 데이터와 동일한 구조)
# cluster_std=1: 표준편차 1 (학습 데이터와 동일)
# random_state=0: 학습 데이터와 동일한 시드값 (같은 분포의 데이터)
# center_box=(5,9): 학습 데이터와 동일한 중심점 범위
X_normal, y_normal = make_blobs(n_samples=200, centers=1, n_features=5, cluster_std=1, random_state=0, center_box=(5,9))
# 테스트용 정상 데이터를 데이터프레임으로 변환
df_normal = pd.DataFrame(X_normal, columns=['x1', 'x2', 'x3', 'x4', 'x5'])
# anomaly_indicator=0: 정상 데이터 표시
df_normal['anomaly_indicator']=0

# 이상 데이터 생성 (테스트 데이터셋용)
# n_samples=20: 테스트용 이상 데이터 20개 생성 (학습 데이터의 1/5 크기)
# centers=2: 2개의 클러스터 중심점
# cluster_std=10: 큰 표준편차로 넓게 퍼진 이상 데이터
# center_box=(10,12): 학습 데이터와 동일한 중심점 범위
X_abnormal, y_abnormal = make_blobs(n_samples=20, centers=2, n_features=5, cluster_std=10, random_state=0, center_box=(10,12))
# 테스트용 이상 데이터를 데이터프레임으로 변환
df_abnormal = pd.DataFrame(X_abnormal, columns=['x1', 'x2', 'x3', 'x4', 'x5'])
# anomaly_indicator=1: 이상 데이터 표시
df_abnormal['anomaly_indicator']=1

# 이상 데이터, 정상데이터 combine (테스트 데이터셋)
# 정상 200개 + 이상 20개 = 총 220개의 테스트 데이터 생성
df = pd.concat([df_normal, df_abnormal])

# %%
# 데이터셋 확인
# head(): 데이터프레임의 앞부분 5개 행을 출력 (기본값)
# 데이터의 구조와 값들을 확인하여 제대로 생성되었는지 검증
df.head()
# Out:
#          x1        x2        x3        x4        x5  anomaly_indicator
# 0  7.299190  7.031186  7.903813  7.269646  5.697052                  0
# 1  7.881233  6.241004  6.558528  7.566263  7.605359                  0
# 2  6.933582  7.681378  6.718283  8.317360  6.525462                  0
# 3  7.401804  6.955763  8.065552  7.640864  5.040028                  0
# 4  8.409498  7.286542  5.288103  8.304289  6.806680                  0

# %% [markdown]
# **결과 설명:**
# - train dataset: (1100, 6) → 학습용 데이터로 정상 데이터 1000개와 이상 데이터 100개로 구성
# - test dataset: (220, 6) → 테스트용 데이터로 정상 데이터 200개와 이상 데이터 20개로 구성
# - 각 데이터셋은 x1~x5까지 5개의 특성과 anomaly_indicator(정상=0, 이상=1) 레이블을 포함
# - 이전 노트북(2차원)과 달리 5차원 데이터를 사용하여 고차원 데이터에서의 이상 탐지 성능을 확인합니다

# %%
# 데이터셋 크기 확인
# shape: 데이터프레임의 (행 개수, 열 개수)를 튜플로 반환
# 학습 데이터셋의 크기 출력: (1100, 6) - 1100개 행, 6개 열 (x1~x5, anomaly_indicator)
print("train dataset:", df_train.shape)
# 테스트 데이터셋의 크기 출력: (220, 6) - 220개 행, 6개 열
print("test dataset:", df.shape)
# Out:
# train dataset: (1100, 6)
# test dataset: (220, 6)

# %%
# X 값 확인 (특성 변수만 추출)
# columns.difference(['anomaly_indicator']): 'anomaly_indicator' 컬럼을 제외한 나머지 컬럼들 선택
# 즉, x1, x2, x3, x4, x5만 추출하여 입력 변수 X를 확인
# anomaly_indicator는 타겟 변수(y)이므로 제외
df[df.columns.difference(['anomaly_indicator'])]
# Out:
#            x1         x2         x3         x4         x5
# 0    7.299190   7.031186   7.903813   7.269646   5.697052
# 1    7.881233   6.241004   6.558528   7.566263   7.605359
# 2    6.933582   7.681378   6.718283   8.317360   6.525462
# 3    7.401804   6.955763   8.065552   7.640864   5.040028
# 4    8.409498   7.286542   5.288103   8.304289   6.806680
# ..        ...        ...        ...        ...        ...
# 15   4.567184   7.279643   3.652083  -5.335501  12.541144
# 16  30.123295  -2.602416  -0.921304  21.621293  -0.964351
# 17  30.250680  22.662970   9.984298   1.219799  21.311400
# 18  -3.446030  11.887964   9.333688  26.417559  25.540897
# 19  18.582694  12.165004  23.177553  -0.420933  14.790299
#
# [220 rows x 5 columns]

# %%
# 데이터 시각화 (임의 변수 선택 - 학습 데이터셋)
# figure(figsize=(6, 4)): 그래프의 크기를 가로 6인치, 세로 4인치로 설정
plt.figure(figsize=(6, 4))
# scatterplot: 산점도 그래프 생성
# x='x1', y='x2': x축과 y축에 각각 x1, x2 특성을 설정 (5차원 중 2개만 선택)
# hue='anomaly_indicator': 색상으로 이상치 여부를 구분 (0=정상, 1=이상)
# data=df_train: 학습 데이터셋 사용
# 5차원 데이터이므로 2차원으로 투영하여 시각화
sns.scatterplot(x='x1', y='x2', hue='anomaly_indicator', data=df_train)
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
# 데이터 시각화 (임의 변수 선택 - 테스트 데이터셋)
# 테스트 데이터셋의 분포를 시각화하여 학습 데이터와 비교
plt.figure(figsize=(6, 4))
# 테스트 데이터셋(df)을 사용하여 산점도 생성
# 학습 데이터와 동일한 구조로 시각화하여 데이터 분포 확인
sns.scatterplot(x='x1', y='x2', hue='anomaly_indicator', data=df)
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# ## **3. 탐색적 데이터 분석(EDA)**

# %% [markdown]
# ### **3-1. 데이터의 변수별 분포 확인**

# %%
# 정상 데이터의 변수별 분포 확인
# df_train.columns: 학습 데이터의 모든 컬럼에 대해 반복
for col in df_train.columns:
    # distplot: 히스토그램과 커널 밀도 추정(KDE)을 함께 그리는 함수
    # loc[df_normal_train[col].notnull(), col]: 해당 컬럼의 결측치가 아닌 값만 선택
    # 정상 데이터(df_normal_train)의 각 특성 변수 분포를 시각화
    sns.distplot(df_normal_train.loc[df_normal_train[col].notnull(), col])
    # 그래프 제목을 현재 컬럼 이름으로 설정
    plt.title(col)
    # 그래프 출력
    plt.show()

# %%
# 이상 데이터의 변수별 분포 확인
# 정상 데이터와 비교하기 위해 이상 데이터의 분포도 확인
for col in df_train.columns:
    # 이상 데이터(df_abnormal_train)의 각 특성 변수 분포를 시각화
    # 이상 데이터는 넓게 퍼진 분포를 보일 것으로 예상됨
    sns.distplot(df_abnormal_train.loc[df_abnormal_train[col].notnull(), col])
    # 그래프 제목 설정
    plt.title(col)
    # 그래프 출력
    plt.show()

# %% [markdown]
# ### **3-2. 정상 데이터와 이상 데이터의 클래스 수 비교**

# %%
# 정상 데이터와 이상 데이터 클래수 비교
plt.figure(figsize=(10,2))
fig = sns.countplot(y=df_train['anomaly_indicator'], data=df_train, palette=["blue", "red"])
plt.show()

# %%
# 정상 데이터와 이상 데이터 클래수 비교
plt.figure(figsize=(10,2))
fig = sns.countplot(y=df['anomaly_indicator'], data=df, palette=["blue", "red"])
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# ## **4. 데이터 전처리**

# %% [markdown]
# ### **4-1. train, validation test 데이터셋 생성**
# - train 데이터: 정상 데이터
# - test 데이터: 정상 + 이상 데이터

# %%
# train 데이터 셋 => X_train, y_train 분할
# X_train: 학습용 입력 변수 (특성 변수만 추출)
# columns.difference(['anomaly_indicator']): 이상치 지표를 제외한 모든 컬럼 선택
# 즉, x1, x2, x3, x4, x5만 포함
X_train = df_train[df_train.columns.difference(['anomaly_indicator'])]
# y_train: 학습용 타겟 변수 (이상치 지표만 추출)
# 0=정상, 1=이상으로 레이블링된 데이터
y_train = df_train["anomaly_indicator"]

# test 데이터 셋 => X_test, y_test 분할
# X_test: 테스트용 입력 변수 (특성 변수만 추출)
X_test = df[df.columns.difference(['anomaly_indicator'])]
# y_test: 테스트용 타겟 변수 (실제 정답 레이블)
# 모델 평가 시 사용할 실제 이상치 여부
y_test = df["anomaly_indicator"]

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# ## **5. 모델 구축**

# %% [markdown]
# ### 5-1. Decision Tree 기반의 앙상블 기법 이상탐지 모델: Isolation Forest
# - 여러 개의 의사결정나무를 종합한 앙상블 기반의 이상탐지 기법으로 의사결정나무를 지속적으로 분기시키면서 모든 데이터 관측치의 고립 정도 여부에 따라 이상치를 판별
# - 대규모 데이터셋에 잘 작동하며, 비선형 데이터에도 유연하게 적용
# > ![nn](../img/7.png)
# > ![nn](../img/8.png)
#
# - 빠르게 고립됨: 이상치일 확률이 높음

# %% [markdown]
# **Isolation Forest 모델 생성 및 학습**
#
# - `IForest()`: Isolation Forest 모델 객체 생성
# - `fit(X_train)`: 학습 데이터로 모델 학습
# - 정상 데이터만으로 학습하므로 비지도 학습 방식입니다

# %%
# Isolation Forest 모델 구축
# IForest: Isolation Forest 모델 객체 생성
# Isolation Forest는 의사결정나무 기반 앙상블 알고리즘으로, 
# 데이터를 랜덤하게 분리하여 이상치를 고립시키는 방식으로 작동
# 정상 데이터만으로 학습하므로 비지도 학습 방식
IForest = IForest()
# fit(): 학습 데이터로 모델 학습
# X_train: 입력 특성 데이터 (정상 데이터 중심으로 학습)
IForest.fit(X_train)
# Out:
# IForest(behaviour='old', bootstrap=False, contamination=0.1, max_features=1.0,
#     max_samples='auto', n_estimators=100, n_jobs=1, random_state=None,
#     verbose=0)

# %%
# train data에 대한 예측 값(정상=0, 이상=1)
# predict(): 학습된 Isolation Forest 모델을 사용하여 예측 수행
# IForest_train_pred: 학습 데이터에 대한 예측 결과 (과적합 확인용)
IForest_train_pred = IForest.predict(X_train) 
# test data에 대한 예측 값(정상=0, 이상=1)
# IForest_test_pred: 테스트 데이터에 대한 예측 결과 (실제 성능 평가용)
# 각 샘플에 대해 0(정상) 또는 1(이상)로 예측
IForest_test_pred = IForest.predict(X_test)

# %%
# Confusion matrix 출력 및 모델 성능 평가 (Isolation Forest 모델)
# confusion_matrix(): 혼동 행렬 생성
# y_test: 실제 정답 레이블 (정상=0, 이상=1)
# IForest_test_pred: Isolation Forest 모델의 예측값
# 결과는 2x2 행렬: [[TN, FP], [FN, TP]]
# TN(True Negative): 정상을 정상으로 예측, FP(False Positive): 정상을 이상으로 예측
# FN(False Negative): 이상을 정상으로 예측, TP(True Positive): 이상을 이상으로 예측
con_mat = confusion_matrix(y_test, IForest_test_pred)

# heatmap(): 혼동 행렬을 히트맵으로 시각화
# pd.DataFrame(): 혼동 행렬을 데이터프레임으로 변환
# xticklabels, yticklabels: x축, y축 레이블 설정
# annot=True: 각 셀에 숫자 값 표시
# fmt="d": 정수 형식으로 표시
# linewidths=.5: 셀 간 경계선 두께
# cmap="YlGnBu": 색상 맵 설정 (노란색-초록색-파란색)
sns.heatmap(pd.DataFrame(con_mat, columns = ['Predicted', 'Actual']),
            xticklabels=['Normal [0]', 'Abnormal [1]'], 
            yticklabels=['Normal [0]', 'Abnormal [1]'], 
            annot=True, fmt="d", linewidths=.5, cmap="YlGnBu")
# y축 레이블: 실제 값 (Actual)
plt.ylabel('Actual')
# x축 레이블: 예측 값 (Predicted)
plt.xlabel('Predicted')

print("accuracy: ", accuracy_score(y_test, IForest_test_pred))
print("recall: ", round(recall_score(y_test, IForest_test_pred),3))
print("precision: ", round(precision_score(y_test, IForest_test_pred),3))
print("f1-score: ", round(f1_score(y_test, IForest_test_pred),3))
# Out:
# accuracy:  0.9863636363636363
# recall:  1.0
# precision:  0.87
# f1-score:  0.93

# %% [markdown]
# **성능 해석:**
# - Isolation Forest는 이 데이터셋에서 매우 우수한 성능을 보입니다

# %% [markdown]
# ### **5-2. 밀도기반 이상탐지 모델: Local Outlier Factor**
# - 각각의 관측치가 데이터 안에서 얼마나 벗어나 있는가에 대한 정도(이상치 정도)를 의미
#     - **모든 데이터를 전체적으로 고려하는 것이 아닌, 해당 관측치의 주변 데이터(neighbor)를 이용하여 국소적(local) 관점으로 이상치 정도를 파악**
# - 지역적인 밀도 차이를 고려하기 때문에, 군집 구조가 있는 데이터에서도 효과적으로 작동
#
# ![nn](../img/9.png)
#
# ![nn](../img/10.png)
#
# - 밀도가 높은 영역 사이에 낮은 밀도를 가진 객체를 이상치로 정의

# %% [markdown]
# **LOF 모델 생성 및 학습**
#
# - `LocalOutlierFactor(contamination=0.1, novelty=True)`: LOF 모델 생성
#   - `contamination=0.1`: 데이터의 10%를 이상치로 간주
#   - `novelty=True`: 새로운 데이터에 대한 예측이 가능하도록 설정
# - `fit(X_train)`: 학습 데이터로 모델 학습

# %%
# LOF 모델 구축 (Local Outlier Factor - 지역적 이상치 인자)
# LocalOutlierFactor: LOF 알고리즘 객체 생성
# contamination=0.1: 데이터의 10%를 이상치로 간주 (비율 설정)
# novelty=True: 새로운 데이터에 대한 예측이 가능하도록 설정
# LOF는 각 데이터 포인트의 지역적 밀도를 계산하여 이상치를 탐지
# 주변 이웃들의 밀도와 비교하여 밀도가 낮은 포인트를 이상치로 판단
LOF = LocalOutlierFactor(contamination=0.1,novelty=True)
# fit(): 학습 데이터로 모델 학습
# X_train: 입력 특성 데이터
LOF.fit(X_train)
# Out:
# LocalOutlierFactor(contamination=0.1, novelty=True)

# %% [markdown]
# **예측값 생성 및 변환**
#
# - LOF 모델의 기본 출력: 정상=1, 이상=-1
# - 다른 모델들과 일관성을 맞추기 위해 정상=0, 이상=1로 변환
# - `replace({-1: 1, 1: 0})`: -1을 1로, 1을 0으로 변환

# %%
# train data에 대한 예측 값(정상=1, 이상=-1)
# predict(): 학습된 LOF 모델을 사용하여 예측 수행
# LOF는 기본적으로 정상=1, 이상=-1로 반환
LOF_train_pred = LOF.predict(X_train) 
# 예측 결과 확인
LOF_train_pred

# test data에 대한 예측 값(정상=1, 이상=-1)
# 테스트 데이터에 대한 예측 수행
LOF_test_pred = LOF.predict(X_test) 
# 데이터프레임으로 변환 (다음 단계에서 처리하기 위해)
LOF_test_pred = pd.DataFrame(LOF_test_pred)
# test data에 대한 예측 값(정상=0, 이상=1)으로 변경
# 다른 모델들과 일관성을 위해 레이블 변환
# -1(이상) -> 1, 1(정상) -> 0으로 변경
LOF_test_pred = LOF_test_pred.replace({-1: 1, 1: 0})
# 변환된 예측 결과 확인
LOF_test_pred
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 215  1
# 216  1
# 217  1
# 218  1
# 219  1
#
# [220 rows x 1 columns]

# %%
# Confusion matrix 출력 및 모델 성능 평가 (LOF 모델)
# confusion_matrix(): LOF 모델의 예측 결과와 실제 값을 비교한 혼동 행렬 생성
# y_test: 실제 정답 레이블 (정상=0, 이상=1)
# LOF_test_pred: LOF 모델의 예측값 (변환된 값)
con_mat = confusion_matrix(y_test, LOF_test_pred)

# heatmap(): 혼동 행렬을 히트맵으로 시각화
sns.heatmap(pd.DataFrame(con_mat, columns = ['Predicted', 'Actual']),
            xticklabels=['Normal [0]', 'Abnormal [1]'], 
            yticklabels=['Normal [0]', 'Abnormal [1]'], 
            annot=True, fmt="d", linewidths=.5, cmap="YlGnBu")
# y축 레이블: 실제 값
plt.ylabel('Actual')
# x축 레이블: 예측 값
plt.xlabel('Predicted')

print("accuracy: ", accuracy_score(y_test, LOF_test_pred))
print("recall: ", round(recall_score(y_test, LOF_test_pred),3))
print("precision: ", round(precision_score(y_test, LOF_test_pred),3))
print("f1-score: ", round(f1_score(y_test, LOF_test_pred),3))
# Out:
# accuracy:  0.9636363636363636
# recall:  0.75
# precision:  0.833
# f1-score:  0.789

# %% [markdown]
# **성능 해석:**
# - Isolation Forest보다 약간 낮은 성능을 보입니다
# - recall이 0.75로 일부 이상 데이터를 놓쳤습니다 (False Negative 발생)
# - 하지만 여전히 좋은 성능을 보이며, 지역적 밀도를 고려하는 장점이 있습니다
# - LOF는 지역적 밀도를 고려하는 장점이 있지만, 이 데이터셋에서는 Isolation Forest가 더 효과적
# - 데이터의 특성에 따라 적합한 알고리즘이 달라질 수 있음
# - LOF는 여러 클러스터가 있는 복잡한 데이터에서 더 유리할 수 있음

# %% [markdown]
# ### **5-3,4. 재구축 기반 이상탐지 모델**
# - 원본 데이터를 압축했다가 다시 원본과 같은 차원으로 복원하는 과정에서 재구축 오차를 통해 이상치 탐색
# - 이상 관측치들은 잘 복원되지 않을 것이라는 가정
#
# ![nn](../img/11.png)

# %% [markdown]
# ### **5-3. 재구축 기반 이상탐지 모델: Pricipal Component Analysis(PCA)**
# - 고차원 데이터에서 이상치를 탐지하는 데 효과적
# - 관측치 (n) 의 고유 분산을 최대한 보존하는 방향으로 변환하는 기저(bais)
#
# > ![nn](../img/12.png)
# ![nn](../img/13.png)

# %% [markdown]
# **PCA 모델 생성 및 학습**
#
# - `PCA()`: PCA 기반 이상 탐지 모델 생성 (pyod 라이브러리)
# - `fit(X_train)`: 학습 데이터로 모델 학습
# - 정상 데이터의 주요 패턴을 학습하여 재구축 기준을 설정합니다

# %%
# PCA 모델 구축 (Principal Component Analysis - 주성분 분석)
# PCA: PYOD 라이브러리의 PCA 기반 이상 탐지 모델 객체 생성
# PCA는 차원 축소를 수행한 후 원본 데이터를 재구축하고, 
# 재구축 오차(reconstruction error)가 큰 데이터를 이상치로 판단
# 정상 데이터는 주성분으로 잘 표현되지만, 이상 데이터는 재구축 오차가 큼
PCA = PCA()
# fit(): 학습 데이터로 모델 학습
# 주성분을 추출하고 재구축 오차의 임계값을 설정
PCA.fit(X_train)
# Out:
# PCA(contamination=0.1, copy=True, iterated_power='auto', n_components=None,
#   n_selected_components=None, random_state=None, standardization=True,
#   svd_solver='auto', tol=0.0, weighted=True, whiten=False)

# %% [markdown]
# **예측값 생성**
#
# - `predict()`: 각 데이터 포인트가 정상(0) 또는 이상(1)인지 예측
# - PCA는 재구축 오차를 계산하여 임계값을 넘으면 이상치로 판단합니다

# %%
# train data에 대한 예측 값(정상=0, 이상=1)
# predict(): 학습된 PCA 모델을 사용하여 예측 수행
# 재구축 오차가 임계값보다 크면 이상치(1), 작으면 정상(0)으로 판단
PCA_train_pred = PCA.predict(X_train) 

# test data에 대한 예측 값(정상=0, 이상=1)
# 테스트 데이터에 대한 예측 수행
# PCA 기반 이상 탐지 결과
PCA_test_pred = PCA.predict(X_test)

# %%
# Confusion matrix 출력 및 모델 성능 평가 (PCA 모델)
# confusion_matrix(): PCA 모델의 예측 결과와 실제 값을 비교한 혼동 행렬 생성
# y_test: 실제 정답 레이블
# PCA_test_pred: PCA 모델의 예측값
con_mat = confusion_matrix(y_test, PCA_test_pred)

# heatmap(): 혼동 행렬을 히트맵으로 시각화
sns.heatmap(pd.DataFrame(con_mat, columns = ['Predicted', 'Actual']),
            xticklabels=['Normal [0]', 'Abnormal [1]'], 
            yticklabels=['Normal [0]', 'Abnormal [1]'], 
            annot=True, fmt="d", linewidths=.5, cmap="YlGnBu")
# y축 레이블: 실제 값
plt.ylabel('Actual')
# x축 레이블: 예측 값
plt.xlabel('Predicted')

print("accuracy: ", accuracy_score(y_test, PCA_test_pred))
print("recall: ", round(recall_score(y_test, PCA_test_pred),3))
print("precision: ", round(precision_score(y_test, PCA_test_pred),3))
print("f1-score: ", round(f1_score(y_test, PCA_test_pred),3))
# Out:
# accuracy:  0.9954545454545455
# recall:  1.0
# precision:  0.952
# f1-score:  0.976

# %% [markdown]
# **성능 해석:**
# - PCA는 이 데이터셋에서 가장 우수한 성능을 보입니다
# - 고차원 데이터(5차원)에서 PCA의 차원 축소 능력이 효과적으로 작동했습니다
# - 재구축 오차 기반 접근법이 이 데이터에 매우 적합합니다

# %% [markdown]
# ### **5-4. 재구축 기반 이상탐지 모델: Auto-Encoder**
# - 복잡한 비선형 관계를 모델링하며 비지도 기반의 학습
#
# > ![nn](../img/14.png)

# %% [markdown]
# 주요 차이점 요약
# | 항목 | PCA 잠재벡터 | Auto-Encoder 잠재벡터 |
# |------|-------------|---------------------|
# | **변환 방식** | 선형 | 비선형 |
# | **계산 방법** | 고유값 분해 | 신경망 학습 |
# | **해석 가능성** | 높음 (수학적) | 낮음 (학습 기반) |
# | **차원 수** | 원본과 동일 | 사용자 설정 가능 |
# | **비선형 관계** | 학습 불가 | 학습 가능 |
# | **계산 속도** | 빠름 | 느림 (학습 필요) |

# %% [markdown]
# **언제 무엇을 사용할까?**
# - **PCA를 사용하는 경우**:
# 데이터가 선형 관계를 가진 경우
# 빠른 계산이 필요한 경우
# 해석 가능성이 중요한 경우
# - **Auto-Encoder를 사용하는 경우**:
# 데이터가 복잡한 비선형 관계를 가진 경우
# 학습 시간이 충분한 경우
# 더 정확한 재구축이 필요한 경우

# %% [markdown]
# **Auto-Encoder 모델 구조 정의**
#
# 이 코드는 TensorFlow/Keras를 사용하여 Auto-Encoder 신경망을 구축합니다.
#
# **모델 구조:**
# - **입력층**: 5차원 (x1~x5)
# - **Encoder**: 5 → 4 → 2 차원으로 점진적으로 압축
# - **Decoder**: 2 → 4 → 5 차원으로 점진적으로 복원
# - **활성화 함수**: ELU (Exponential Linear Unit) - 비선형 관계 학습
#
# **각 레이어의 역할:**
# - `Dense(input_dim, activation='elu')`: 입력을 받아 첫 번째 은닉층으로 전달
# - `Dense(4, activation='elu')`: 중간 압축 단계
# - `Dense(2, activation='elu')`: 최종 압축 (잠재 공간)
# - `Dense(4, activation='elu')`: 복원 시작
# - `Dense(input_dim, activation='elu')`: 원본 차원으로 복원
#
# **컴파일:**
# - `optimizer='adam'`: 학습 알고리즘
# - `loss='mse'`: 평균 제곱 오차 (Mean Squared Error) - 재구축 오차를 최소화

# %%
# Auto-Encoder 모델 구조 정의
# input_dim: 입력 차원 수 (특성 개수)
# X_train.shape[1]: 학습 데이터의 컬럼 개수 (5개 특성)
input_dim = X_train.shape[1]

# Sequential: 순차적 레이어를 쌓는 모델 구조
# Auto-Encoder는 인코더(압축)와 디코더(복원)로 구성
AE = tf.keras.models.Sequential([
    
    # encode (인코더 - 차원 축소)
    # 첫 번째 은닉층: 입력 차원을 받아 첫 번째 은닉층으로 전달
    # activation='elu': ELU 활성화 함수 사용 (Exponential Linear Unit)
    tf.keras.layers.Dense(input_dim, activation='elu', input_shape=(input_dim, )), 
    # 두 번째 은닉층: 중간 압축 단계 (4차원으로 축소)
    tf.keras.layers.Dense(4, activation='elu'),
    # 세 번째 은닉층: 최종 압축 (잠재 공간, 2차원으로 축소)
    # 이 2차원 공간에 데이터의 핵심 정보가 압축됨
    tf.keras.layers.Dense(2, activation='elu'),
    
    # decode (디코더 - 차원 복원)
    # 네 번째 은닉층: 2차원에서 4차원으로 확장
    tf.keras.layers.Dense(4, activation='elu'),
    # 출력층: 원본 차원으로 복원 (5차원)
    # 이상 데이터는 재구축 오차가 클 것
    tf.keras.layers.Dense(input_dim, activation='elu')
    
])

# compile: 모델 컴파일 (학습 설정)
# optimizer="adam": Adam 최적화 알고리즘 사용 (적응적 학습률)
# loss="mse": 평균 제곱 오차(Mean Squared Error)를 손실 함수로 사용
# 재구축 오차를 최소화하도록 학습
AE.compile(optimizer="adam", loss="mse")
# summary: 모델 구조 요약 출력 (레이어별 파라미터 수 확인)
AE.summary();
# Out:
# W0000 00:00:1764034075.788560   94056 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 5)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# **Auto-Encoder 모델 학습**
#
# - `fit()`: 모델을 학습 데이터로 학습
# - `epochs=100`: 전체 데이터를 100번 반복 학습
# - `batch_size=32`: 한 번에 32개 샘플씩 학습
# - `validation_split=0.3`: 학습 데이터의 30%를 검증용으로 사용
#
# **학습 과정:**
# - 입력과 출력이 동일하도록 학습 (X_train → X_train)
# - 정상 데이터의 패턴을 학습하여 재구축 능력을 향상시킵니다
# - 학습이 진행될수록 loss가 감소하여 재구축 오차가 줄어듭니다

# %%
history = AE.fit(
    X_train,
    X_train,
    epochs=100,
    batch_size=32,
    validation_split=0.3
)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 55.9604 - val_loss: 104.4837
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 54.7242 - val_loss: 103.0936
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 52.7044 - val_loss: 98.1730
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.8318 - val_loss: 88.1133
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.6462 - val_loss: 78.8690
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.6018 - val_loss: 73.0321
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.9577 - val_loss: 68.7267
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.0697 - val_loss: 64.6713
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.2121 - val_loss: 61.6089
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.4801 - val_loss: 59.1856
# Epoch 11/100
# ...

# %%
# 학습 과정 시각화
# plot: 학습 손실과 검증 손실을 그래프로 표시
# history.history["loss"]: 각 에포크별 학습 손실값
# history.history["val_loss"]: 각 에포크별 검증 손실값
# 학습이 잘 되면 두 손실값이 모두 감소하며 수렴
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
# legend: 범례 표시
plt.legend()
# 그래프 출력
plt.show()

# %% [markdown]
# **학습 과정 시각화**
#
# - Training Loss: 학습 데이터에 대한 재구축 오차
# - Validation Loss: 검증 데이터에 대한 재구축 오차
# - 두 곡선이 모두 감소하면 정상적으로 학습이 되고 있습니다.

# %% [markdown]
# **학습 데이터에 대한 재구축 오차 계산**
#
# - `AE.predict(X_train)`: 학습 데이터를 재구축
# - `np.mean(np.power(X_train - AE_train_pred, 2), axis=1)`: 각 샘플의 재구축 오차(MSE) 계산
# - **Reconstruction Error (재구축 오차)**: 원본과 재구축된 데이터 간의 차이
# - 이 값이 클수록 모델이 해당 데이터를 잘 재구축하지 못했다는 의미입니다

# %%
# train data에 대한 예측 값
# predict(): 학습된 Auto-Encoder 모델을 사용하여 학습 데이터를 재구축
# AE_train_pred: 재구축된 데이터 (원본과 같은 차원)
AE_train_pred = AE.predict(X_train)

# 실제 값과 예측 값 사이의 차이인 MSE값을 reconstruction error로 정의 -> Novelty Score
# np.power(X_train - AE_train_pred, 2): 원본과 재구축 데이터 간의 차이의 제곱
# np.mean(..., axis=1): 각 샘플별로 평균을 계산 (MSE - Mean Squared Error)
# 재구축 오차가 클수록 이상치일 가능성이 높음
train_mse = np.mean(np.power(X_train - AE_train_pred, 2), axis=1)
# 데이터프레임으로 변환하여 저장
train_mse = pd.DataFrame({'Reconstruction_error': train_mse})
# 재구축 오차 확인
train_mse
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#     Reconstruction_error
# 0               0.302056
# 1               0.806302
# 2               1.413389
# 3               0.409332
# 4               0.511838
# ..                   ...
# 95            178.257359
# 96             59.495394
# 97             99.144551
# 98            114.055429
# 99             20.211165
#
# [1100 rows x 1 columns]

# %% [markdown]
# **임계값(Threshold) 설정**
#
# - `np.percentile(..., 90)`: 학습 데이터의 재구축 오차 상위 10% 값을 임계값으로 설정
# - 즉, 학습 데이터의 10%를 이상치로 간주하는 것과 같습니다
# - 이 임계값을 넘으면 이상치로 판단합니다
# - `contamination=0.1`과 유사한 개념입니다

# %%
# train 데이터에 대한 novelty score 기준 상위 10% 의 값을 임계치로 설정
# sorted(): 재구축 오차를 오름차순으로 정렬
# np.percentile(..., 90): 90번째 퍼센타일 값 계산 (상위 10%의 하한값)
# 즉, 학습 데이터의 10%를 이상치로 간주하는 것과 같음
# 이 임계값을 넘으면 이상치로 판단 (contamination=0.1과 유사한 개념)
AE_thresh = np.percentile(sorted(train_mse['Reconstruction_error']), 90)
# 계산된 임계값 출력
AE_thresh
# Out:
# np.float64(2.694244356502083)

# %%
# 학습 데이터의 재구축 오차 시각화
# plot(): 학습 데이터의 재구축 오차를 선 그래프로 표시
# 재구축 오차의 분포를 확인하여 임계값 설정의 적절성 검증
plt.plot(train_mse)

# %% [markdown]
# **학습 데이터 재구축 오차 시각화**
#
# - 각 학습 데이터 샘플의 재구축 오차를 그래프로 표시
# - 대부분의 데이터는 낮은 오차를 가지지만, 일부는 높은 오차를 가집니다
# - 높은 오차를 가진 데이터들이 이상치 후보입니다

# %% [markdown]
# **테스트 데이터에 대한 재구축 오차 계산**
#
# - `AE.predict(X_test)`: 테스트 데이터를 재구축
# - `np.mean(np.power(X_test - AE_test_pred, 2), axis=1)`: 각 테스트 샘플의 재구축 오차 계산
# - 이 오차를 위에서 설정한 임계값과 비교하여 이상치를 판단합니다

# %%
# test data에 대한 예측 값
AE_test_pred = AE.predict(X_test)

# 실제 값과 예측 값 사이의 차이인 MSE값을 reconstruction error로 정의
test_mse = np.mean(np.power(X_test - AE_test_pred, 2), axis=1)
test_mse
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 0       0.329206
# 1       0.861634
# 2       0.340564
# 3       0.795698
# 4       1.401392
#          ...
# 15     54.486876
# 16    207.790467
# 17    163.039479
# 18    218.065154
# 19     75.009124
# Length: 220, dtype: float64

# %%
# 테스트 데이터의 재구축 오차 시각화
# plot(): 테스트 데이터의 재구축 오차를 선 그래프로 표시
# 학습 데이터와 비교하여 이상치 탐지 성능 확인
plt.plot(test_mse.values)

# %% [markdown]
# **테스트 데이터 재구축 오차 시각화**
#
# - 각 테스트 데이터 샘플의 재구축 오차를 그래프로 표시
# - 오차가 임계값을 넘는 데이터들이 이상치로 판단됩니다
# - 실제 이상 데이터는 높은 오차를 가질 가능성이 높습니다

# %% [markdown]
# **Novelty Classifier 함수 정의**
#
# 이 함수는 재구축 오차를 기반으로 이상치를 분류합니다.
#
# **작동 방식:**
# - 각 테스트 샘플의 재구축 오차를 확인
# - 오차가 임계값(`AE_thresh`)보다 크면 → 이상치(1)
# - 오차가 임계값보다 작으면 → 정상(0)
#
# **Novelty Score:**
# - 재구축 오차를 Novelty Score라고도 부릅니다
# - 높을수록 모델이 학습한 패턴에서 벗어난 데이터입니다

# %%
# classifier
# AE_thresh 기준, test_mse 값이 더 크면 이상(1), 작으면 정상(0)으로 분류
AE_test_df = []

def novelty_classifier(novelty_score):
    for i in range(len(novelty_score)):
        if novelty_score[i] > AE_thresh:
            AE_test_df.append(1)
        else:
            AE_test_df.append(0)

# %% [markdown]
# **Novelty Classifier 실행**
#
# - `novelty_classifier(test_mse.values)`: 테스트 데이터의 재구축 오차를 입력하여 이상치 분류
# - 결과는 `AE_test_df` 리스트에 저장됩니다 (정상=0, 이상=1)

# %%
# novelty_classifier 함수 실행
# test_mse.values: 테스트 데이터의 재구축 오차 배열
# 함수를 실행하면 AE_test_df 리스트에 분류 결과가 저장됨 (정상=0, 이상=1)
novelty_classifier(test_mse.values)

# %%
# Confusion matrix 출력 및 모델 성능 평가 (Auto-Encoder 모델)
# confusion_matrix(): Auto-Encoder 모델의 예측 결과와 실제 값을 비교한 혼동 행렬 생성
# y_test: 실제 정답 레이블 (정상=0, 이상=1)
# AE_test_df: Auto-Encoder 모델의 예측값 (재구축 오차 기반 분류 결과)
con_mat = confusion_matrix(y_test, AE_test_df)

# heatmap(): 혼동 행렬을 히트맵으로 시각화
sns.heatmap(pd.DataFrame(con_mat, columns = ['Predicted', 'Actual']),
            xticklabels=['Normal [0]', 'Abnormal [1]'], 
            yticklabels=['Normal [0]', 'Abnormal [1]'], 
            annot=True, fmt="d", linewidths=.5, cmap="YlGnBu")
# y축 레이블: 실제 값
plt.ylabel('Actual')
# x축 레이블: 예측 값
plt.xlabel('Predicted')

print("accuracy: ", accuracy_score(y_test, AE_test_df))
print("recall: ", round(recall_score(y_test, AE_test_df),3))
print("precision: ", round(precision_score(y_test, AE_test_df),3))
print("f1-score: ", round(f1_score(y_test, AE_test_df),3))
# Out:
# accuracy:  0.9863636363636363
# recall:  1.0
# precision:  0.87
# f1-score:  0.93

# %% [markdown]
# **성능 해석:**
# - Auto-Encoder는 Isolation Forest와 동일한 성능을 보입니다
# - 딥러닝 기반 접근법으로 비선형 관계를 학습할 수 있습니다
# - 재구축 오차 기반 접근법이 효과적으로 작동했습니다
#
# **모델 비교 요약:**
# 1. **PCA**: accuracy 0.995 (최고 성능)
# 2. **Isolation Forest**: accuracy 0.986
# 3. **Auto-Encoder**: accuracy 0.986
# 4. **LOF**: accuracy 0.964
#
# 이 데이터셋에서는 PCA가 가장 우수한 성능을 보였습니다.
