# %% [markdown]
# # **이상탐지1: 수업실습용**
#
# 이 노트북은 이상 탐지(Anomaly Detection)의 4가지 주요 방법을 실습하는 자료입니다:
# 1. **K-Nearest Neighbors (KNN)**: 거리 기반 이상 탐지
# 2. **K-Means Clustering**: 클러스터링 기반 이상 탐지
# 3. **Gaussian Density Estimation (GDE)**: 단일 가우시안 분포 기반 이상 탐지
# 4. **Mixture of Gaussian (MOG)**: 다중 가우시안 분포 혼합 모델 기반 이상 탐지
#
# 각 방법의 원리와 구현 방법을 학습하고, 결과를 비교 분석합니다.

# %% [markdown]
# ## **1. 라이브러리 로드**
#
# 필요한 라이브러리들을 import합니다:
# - **pandas, numpy**: 데이터 처리 및 수치 연산
# - **sklearn**: 머신러닝 모델 및 평가 지표
# - **matplotlib, seaborn**: 데이터 시각화

# %%
# pandas: 데이터프레임을 다루기 위한 라이브러리 (데이터 조작 및 분석)
import pandas as pd
# numpy: 수치 연산을 위한 라이브러리 (배열 연산, 수학 함수)
import numpy as np
# warnings: 경고 메시지를 제어하기 위한 모듈
import warnings
# 모든 경고 메시지를 무시하도록 설정 (코드 실행 시 경고가 출력되지 않음)
warnings.filterwarnings(action='ignore') 
# Jupyter 노트북에서 matplotlib 그래프를 인라인으로 표시하도록 설정
# %matplotlib inline

# 데이터 전처리 패키지
# EllipticEnvelope: 가우시안 분포를 이용한 이상치 탐지 모델 (GDE - Gaussian Distribution Estimation)
from sklearn.covariance import EllipticEnvelope
# train_test_split: 데이터를 학습용과 테스트용으로 분할하는 함수
from sklearn.model_selection import train_test_split

# 모델 패키지

# make_blobs: 클러스터링을 위한 가상의 데이터셋을 생성하는 함수
from sklearn.datasets import make_blobs
# GaussianMixture: 가우시안 혼합 모델 (GMM - Gaussian Mixture Model) - MOG에 사용
from sklearn.mixture import GaussianMixture
# KMeans: K-means 클러스터링 알고리즘
from sklearn.cluster import KMeans
# GridSearchCV: 하이퍼파라미터 최적화를 위한 그리드 서치 교차 검증
from sklearn.model_selection import GridSearchCV
# KNeighborsClassifier: K-최근접 이웃 분류기 (KNN)
from sklearn.neighbors import KNeighborsClassifier

# 모델 평가 패키지
# metrics: 분류 모델의 성능 평가 지표들 (정확도, 정밀도, 재현율 등)
from sklearn import metrics
# train_test_split: 데이터 분할 함수 (중복 import이지만 문제없음)
from sklearn.model_selection import train_test_split
# confusion_matrix: 혼동 행렬을 생성하는 함수 (실제값과 예측값의 비교)
from sklearn.metrics import confusion_matrix

# 시각화 패키지
# matplotlib: 기본적인 그래프 그리기 라이브러리
import matplotlib
# pyplot: matplotlib의 그래프 그리기 인터페이스
import matplotlib.pyplot as plt
# seaborn: matplotlib 기반의 고급 시각화 라이브러리 (통계 그래프에 특화)
import seaborn as sns
# seaborn의 스타일을 'white'로 설정 (흰색 배경의 깔끔한 그래프)
sns.set_style('white')

# 마이너스 기호(-) 깨짐 방지
# matplotlib에서 마이너스 기호가 깨지지 않도록 설정 (한글 환경에서 주로 발생하는 문제)
matplotlib.rcParams['axes.unicode_minus'] = False

# # 한글 폰트 사용하기
# # 주석 처리됨: 한글을 그래프에 표시할 때 사용하는 폰트 설정 (필요시 주석 해제)
# plt.rc('font', family='Malgun Gothic')

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# ## **2. 이상치 데이터 셋 임의로 생성**

# %% [markdown]
# - make_blobs: 서로 다른 클러스터를 형성하는 데이터를 생성하는 함수
# - 입력 매개변수:
#     - n_samples: 생성할 데이터 포인트의 수.
#     - n_features: 각 데이터 포인트의 특성(차원) 수.
#     - centers: 클러스터의 중심 수 또는 중심의 좌표.
#     - cluster_std: 각 클러스터의 표준 편차로, 클러스터의 분산 정도를 조절합니다.
#     - random_state: 난수 생성 시드로, 동일한 결과를 재현할 수 있도록 합니다.

# %% [markdown]
# **train 데이터셋 생성**
#
# - 정상 데이터: 1000개, 3개의 클러스터 중심, 표준편차 1 (밀집된 정상 데이터)
# - 이상 데이터: 100개, 1개의 클러스터 중심, 표준편차 10 (분산이 큰 이상 데이터)
# - anomaly_indicator: 0(정상), 1(이상) 레이블 추가

# %%
# 정상 데이터 생성
# make_blobs: 가상의 클러스터 데이터를 생성
# n_samples=1000: 정상 데이터 1000개 생성
# centers=3: 3개의 클러스터 중심점 생성
# n_features=2: 2개의 특성(feature)을 가진 데이터 생성
# cluster_std=1: 클러스터의 표준편차를 1로 설정 (작은 값이므로 밀집된 클러스터)
# random_state=42: 재현 가능한 결과를 위한 시드값 설정
X_normal_train, y_normal_train = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=1, random_state=42)
# 생성된 정상 데이터를 데이터프레임으로 변환
# feature1, feature2: 두 개의 특성 컬럼
# anomaly_indicator=0: 정상 데이터이므로 이상치 지표를 0으로 설정
df_normal_train = pd.DataFrame({'feature1': X_normal_train[:, 0], 'feature2': X_normal_train[:, 1], 'anomaly_indicator': 0})

# 이상 데이터 생성
# n_samples=100: 이상 데이터 100개 생성 (정상 데이터보다 적음)
# centers=1: 1개의 클러스터 중심점
# cluster_std=10: 표준편차를 10으로 설정 (큰 값이므로 넓게 퍼진 데이터 = 이상치)
# random_state=0: 다른 시드값 사용 (정상 데이터와 다른 분포)
X_abnormal_train, y_abnormal_train = make_blobs(n_samples=100, centers=1, n_features=2, cluster_std =10, random_state=0)
# 생성된 이상 데이터를 데이터프레임으로 변환
# anomaly_indicator=1: 이상 데이터이므로 이상치 지표를 1로 설정
df_abnormal_train = pd.DataFrame({'feature1': X_abnormal_train[:, 0], 'feature2': X_abnormal_train[:, 1], 'anomaly_indicator': 1})

# 이상 데이터, 정상데이터 combine
# pd.concat: 두 데이터프레임을 세로로 결합 (행 결합)
# 최종적으로 정상 1000개 + 이상 100개 = 총 1100개의 학습 데이터 생성
df_train = pd.concat([df_normal_train, df_abnormal_train])

# %% [markdown]
# **test 데이터셋 생성**
#
# - 정상 데이터: 500개 (train의 절반 크기)
# - 이상 데이터: 50개 (train의 절반 크기)
# - train과 동일한 파라미터로 생성하여 일관성 유지

# %%
# 정상 데이터 생성 (테스트 데이터셋용)
# n_samples=500: 테스트용 정상 데이터 500개 생성 (학습 데이터보다 적음)
# centers=3: 3개의 클러스터 중심점 (학습 데이터와 동일한 구조)
# cluster_std=1: 표준편차 1 (학습 데이터와 동일)
# random_state=42: 학습 데이터와 동일한 시드값 (같은 분포의 데이터)
X_normal, y_normal = make_blobs(n_samples=500, centers=3, n_features=2, cluster_std=1, random_state=42)
# 테스트용 정상 데이터를 데이터프레임으로 변환
# anomaly_indicator=0: 정상 데이터 표시
df_normal = pd.DataFrame({'feature1': X_normal[:, 0], 'feature2': X_normal[:, 1], 'anomaly_indicator': 0})

# 이상 데이터 생성 (테스트 데이터셋용)
# n_samples=50: 테스트용 이상 데이터 50개 생성
# centers=1: 1개의 클러스터 중심점
# cluster_std=10: 큰 표준편차로 넓게 퍼진 이상 데이터
# random_state=0: 학습 데이터와 동일한 시드값
X_abnormal, y_abnormal = make_blobs(n_samples=50, centers=1, n_features=2, cluster_std =10, random_state=0)
# 테스트용 이상 데이터를 데이터프레임으로 변환
# anomaly_indicator=1: 이상 데이터 표시
df_abnormal = pd.DataFrame({'feature1': X_abnormal[:, 0], 'feature2': X_abnormal[:, 1], 'anomaly_indicator': 1})

# 이상 데이터, 정상데이터 combine (테스트 데이터셋)
# 정상 500개 + 이상 50개 = 총 550개의 테스트 데이터 생성
df = pd.concat([df_normal, df_abnormal])

# %%
# 데이터셋 확인
# head(): 데이터프레임의 앞부분 5개 행을 출력 (기본값)
# 데이터의 구조와 값들을 확인하여 제대로 생성되었는지 검증
df.head()
# Out:
#    feature1  feature2  anomaly_indicator
# 0 -5.730354 -7.583286                  0
# 1  1.942992  1.918875                  0
# 2  6.829682  1.164871                  0
# 3 -2.901306  7.550771                  0
# 4  5.841093  1.565094                  0

# %%
# 데이터셋 크기 확인
# shape: 데이터프레임의 (행 개수, 열 개수)를 튜플로 반환
# 학습 데이터셋의 크기 출력: (1100, 3) - 1100개 행, 3개 열 (feature1, feature2, anomaly_indicator)
print("train dataset:", df_train.shape)
# 테스트 데이터셋의 크기 출력: (550, 3) - 550개 행, 3개 열
print("test dataset:", df.shape)
# Out:
# train dataset: (1100, 3)
# test dataset: (550, 3)

# %%
# 데이터의 column 값 확인
# keys(): 데이터프레임의 모든 컬럼 이름을 Index 객체로 반환
# 데이터프레임에 어떤 컬럼들이 있는지 확인
print(df.keys())
# Out:
# Index(['feature1', 'feature2', 'anomaly_indicator'], dtype='object')

# %%
# X 값 확인 (특성 변수만 추출)
# columns.difference(['anomaly_indicator']): 'anomaly_indicator' 컬럼을 제외한 나머지 컬럼들 선택
# 즉, feature1과 feature2만 추출하여 입력 변수 X를 확인
# anomaly_indicator는 타겟 변수(y)이므로 제외
df[df.columns.difference(['anomaly_indicator'])]
# Out:
#      feature1   feature2
# 0   -5.730354  -7.583286
# 1    1.942992   1.918875
# 2    6.829682   1.164871
# 3   -2.901306   7.550771
# 4    5.841093   1.565094
# ..        ...        ...
# 45  15.917061   2.252205
# 46  16.304062  18.997375
# 47   2.750532   0.285978
# 48  -4.120252  -0.076956
# 49   5.414902   7.640531
#
# [550 rows x 2 columns]

# %%
# 데이터 시각화 (학습 데이터셋)
# figure(figsize=(12, 8)): 그래프의 크기를 가로 12인치, 세로 8인치로 설정
plt.figure(figsize=(12, 8))
# scatterplot: 산점도 그래프 생성
# x='feature1', y='feature2': x축과 y축에 각각 feature1, feature2를 설정
# hue='anomaly_indicator': 색상으로 이상치 여부를 구분 (0=정상, 1=이상)
# data=df_train: 학습 데이터셋 사용
# 정상 데이터와 이상 데이터의 분포를 시각적으로 확인
sns.scatterplot(x='feature1', y='feature2', hue='anomaly_indicator', data=df_train)
# Out:
# <Axes: xlabel='feature1', ylabel='feature2'>

# %% [markdown]
# **train 데이터 시각화**
#
# - feature1과 feature2를 축으로 하는 산점도
# - 색상으로 정상(0)과 이상(1) 데이터를 구분
# - 정상 데이터는 3개의 밀집된 클러스터로, 이상 데이터는 넓게 분산되어 있음을 확인

# %%
# 데이터 시각화 (테스트 데이터셋)
# 테스트 데이터셋의 분포를 시각화하여 학습 데이터와 비교
plt.figure(figsize=(12, 8))
# 테스트 데이터셋(df)을 사용하여 산점도 생성
# 학습 데이터와 동일한 구조로 시각화하여 데이터 분포 확인
sns.scatterplot(x='feature1', y='feature2', hue='anomaly_indicator', data=df)
# Out:
# <Axes: xlabel='feature1', ylabel='feature2'>

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# **test 데이터 시각화**
#
# - test 데이터셋의 분포를 확인
# - train 데이터와 유사한 패턴을 보이지만 데이터 개수가 적음
#
# **정상 데이터의 변수별 분포 확인**
#
# - feature1과 feature2 각각의 분포를 히스토그램으로 확인
# - 정상 데이터는 정규분포에 가까운 형태를 보이며, 여러 개의 피크(클러스터)가 있을 수 있음

# %% [markdown]
# ## **3. 탐색적 데이터 분석(EDA)**

# %% [markdown]
# **이상 데이터의 변수별 분포 확인**
#
# **왜 이상 데이터가 넓게 퍼져있나요?**
# - 정상 데이터: `cluster_std=1` (표준편차 1) → 데이터가 클러스터 중심 주변에 밀집
# - 이상 데이터: `cluster_std=10` (표준편차 10) → 데이터가 클러스터 중심에서 넓게 분산
# - **표준편차가 10배 크기 때문에** 이상 데이터는 -40~40 범위까지 넓게 퍼져있습니다
#
# **분포의 특징:**
# - 정상 데이터: 3개의 뚜렷한 봉우리 (3개 클러스터, centers=3)
# - 이상 데이터: 1개의 넓은 봉우리 (1개 클러스터, centers=1)이지만 매우 넓게 퍼져있음
# - Density 값이 낮고 넓게 분산 → 정상 데이터와 명확히 구분 가능
# - 이렇게 넓게 퍼진 특성이 이상 탐지 알고리즘이 이상치를 찾을 수 있는 핵심입니다

# %% [markdown]
# ### **3-1. 데이터의 변수별 분포 확인**

# %% [markdown]
# **train 데이터 클래스 불균형 확인**
#
# - 정상 데이터(0)와 이상 데이터(1)의 개수를 비교
# - 이상 탐지 문제는 일반적으로 클래스 불균형이 심한 편입니다 (정상 데이터가 훨씬 많음)
# - 이 노트북에서는 10:1 비율로 생성했습니다

# %%
# 정상 데이터의 변수별 분포 확인
# columns.difference(['anomaly_indicator']): 이상치 지표를 제외한 모든 특성 변수에 대해 반복
for col in df_train.columns.difference(['anomaly_indicator']):
    # distplot: 히스토그램과 커널 밀도 추정(KDE)을 함께 그리는 함수
    # loc[df_normal_train[col].notnull(), col]: 해당 컬럼의 결측치가 아닌 값만 선택
    # 정상 데이터(df_normal_train)의 각 특성 변수 분포를 시각화
    sns.distplot(df_normal_train.loc[df_normal_train[col].notnull(), col])
    # 그래프 제목을 현재 컬럼 이름으로 설정
    plt.title(col)
    # 그래프 출력
    plt.show()

# %% [markdown]
# **test 데이터 클래스 불균형 확인**
#
# - test 데이터셋에서도 동일한 클래스 비율을 확인

# %%
# 이상 데이터의 변수별 분포 확인
# 정상 데이터와 비교하기 위해 이상 데이터의 분포도 확인
for col in df_train.columns.difference(['anomaly_indicator']):
    # 이상 데이터(df_abnormal_train)의 각 특성 변수 분포를 시각화
    # 이상 데이터는 넓게 퍼진 분포를 보일 것으로 예상됨
    sns.distplot(df_abnormal_train.loc[df_abnormal_train[col].notnull(), col])
    # 그래프 제목 설정
    plt.title(col)
    # 그래프 출력
    plt.show()

# %% [markdown]
# **데이터 분할**
#
# - X_train, X_test: 특성 데이터 (feature1, feature2)
# - y_train, y_test: 레이블 데이터 (anomaly_indicator)
# - 이상 탐지에서는 일반적으로 정상 데이터만으로 학습하지만, 이 실습에서는 레이블이 있는 데이터로 학습합니다

# %% [markdown]
# ### **3-2. 정상 데이터와 이상 데이터의 클래스 수 비교**

# %%
# 정상 데이터와 이상 데이터 클래스 비교 (학습 데이터셋)
# countplot: 범주형 변수의 빈도를 막대 그래프로 표시
# figsize=(10,2): 가로로 긴 그래프 크기 설정
plt.figure(figsize=(10,2))
# y=df_train['anomaly_indicator']: y축에 이상치 지표를 설정 (가로 막대 그래프)
# data=df_train: 학습 데이터셋 사용
# palette=["blue", "red"]: 정상(0)은 파란색, 이상(1)은 빨간색으로 표시
# 클래스 불균형 정도를 확인 (정상 데이터가 훨씬 많을 것으로 예상)
fig = sns.countplot(y=df_train['anomaly_indicator'], data=df_train, palette=["blue", "red"])
plt.show()

# %%
# 정상 데이터와 이상 데이터 클래스 비교 (테스트 데이터셋)
# 테스트 데이터셋의 클래스 분포를 확인하여 학습 데이터와 비교
plt.figure(figsize=(10,2))
# 테스트 데이터셋(df)을 사용하여 클래스 분포 시각화
fig = sns.countplot(y=df['anomaly_indicator'], data=df, palette=["blue", "red"])
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# ## **4. 데이터 전처리**

# %% [markdown]
# ### **4-1. train, validation test 데이터셋 생성**
# - train 데이터: 정상 데이터
# - test 데이터: 정상 + 이상 데이터

# %%
# train 데이터 셋 => X_train, y_train 분할
# X_train: 학습용 입력 변수 (특성 변수만 추출)
# columns.difference(['anomaly_indicator']): 이상치 지표를 제외한 모든 컬럼 선택
# 즉, feature1과 feature2만 포함
X_train = df_train[df_train.columns.difference(['anomaly_indicator'])]
# y_train: 학습용 타겟 변수 (이상치 지표만 추출)
# 0=정상, 1=이상으로 레이블링된 데이터
y_train = df_train["anomaly_indicator"]

# test 데이터 셋 => X_test, y_test 분할
# X_test: 테스트용 입력 변수 (특성 변수만 추출)
X_test = df[df.columns.difference(['anomaly_indicator'])]
# y_test: 테스트용 타겟 변수 (실제 정답 레이블)
# 모델 평가 시 사용할 실제 이상치 여부
y_test = df["anomaly_indicator"]

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# ## **5. 모델 구축**

# %% [markdown]
# ### **5-1. 거리기반 이상탐지 모델: K-Nearst-Neighbors**
# - 새로운 데이터가 들어왔을 때 k개의 가장 가까이 있는 데이터들과 비교하여 예측하고 분류하는 알고리즘
# > ![nn](../img/1.png)
#
# - 빨간 별: 새로운 데이터
# - k: 임의의 수
#     - 데이터셋의 특성과 분류 문제의 성격에 따라 적절한 K값을 선택
#         - 데이터셋이 노이즈가 많은 경우 작은 K값
#         - 데이터셋이 복잡한 패턴을 가지고 있거나 클래스 간 경계가 모호한 경우 큰 K값

# %% [markdown]
# **(1) 모델 생성 및 학습**

# %% [markdown]
# **그리드 서치를 활용한 하이퍼파라미터 설정**
# - 그리드 서치란?
#     - 모델 하이퍼 파라미터에 넣을 수 있는 값들을 순차적으로 입력한뒤에 가장 높은 성능을 보이는 하이퍼 파라미터들을 찾는 탐색 방법
#     > ![nn](../img/2.png)

# %% [markdown]
# **grid_params 설명:**
#
# 이 딕셔너리는 KNN 모델의 하이퍼파라미터 후보값들을 정의합니다.
#
# - **n_neighbors**: [5,7,9,11,13,15] → 고려할 이웃의 개수 (6개 옵션)
#   - 작은 값(5): 지역적 패턴에 민감, 노이즈에 취약
#   - 큰 값(15): 더 부드러운 경계, 전역적 패턴 반영
#
# - **weights**: ['uniform','distance'] → 이웃에 부여할 가중치 방식 (2개 옵션)
#   - 'uniform': 모든 이웃에 동일한 가중치 (1/k)
#   - 'distance': 거리에 반비례하는 가중치 (가까운 이웃에 더 큰 영향)
#
# - **metric**: ['minkowski','euclidean','manhattan'] → 거리 측정 방법 (3개 옵션)
#   - 'euclidean': 유클리드 거리 (직선 거리) √(x₁-x₂)² + (y₁-y₂)²
#   - 'manhattan': 맨해튼 거리 (L1 거리) |x₁-x₂| + |y₁-y₂|
#   - 'minkowski': 민코프스키 거리 (유클리드의 일반화)
#
# **총 조합 수**: 6 × 2 × 3 = **36개의 하이퍼파라미터 조합**을 시도합니다

# %%
# Hyperparameter (하이퍼파라미터 설정)
# GridSearchCV를 사용하여 최적의 하이퍼파라미터를 찾기 위한 그리드 설정
grid_params = { 
    # n_neighbors: KNN에서 사용할 이웃의 개수 (K 값)
    # 5, 7, 9, 11, 13, 15 중에서 최적값을 찾음
    'n_neighbors' : [5,7,9,11,13,15],
    # weights: 이웃들의 가중치 계산 방법
    # 'uniform': 모든 이웃에 동일한 가중치 부여
    # 'distance': 거리에 반비례하는 가중치 부여 (가까운 이웃에 더 큰 영향)
    'weights' : ['uniform','distance'],
    # metric: 거리 측정 방법
    # 'minkowski': 민코프스키 거리 (일반화된 유클리드 거리)
    # 'euclidean': 유클리드 거리 (직선 거리)
    # 'manhattan': 맨해튼 거리 (L1 거리, 격자 형태의 거리)
    'metric' : ['minkowski','euclidean','manhattan']
}

# %%
# KNN 모델 생성 후 GridSearchCV 수행
# GridSearchCV: 그리드 서치 교차 검증을 수행하는 객체 생성
# KNeighborsClassifier(): KNN 분류기 객체 (기본 파라미터로 초기화)
# grid_params: 위에서 정의한 하이퍼파라미터 그리드
# verbose=1: 진행 상황을 출력 (1=상세 정보 출력)
# cv=3: 3-fold 교차 검증 사용 (데이터를 3개로 나누어 검증)
# n_jobs=-1: 모든 CPU 코어를 사용하여 병렬 처리 (빠른 실행)
gs = GridSearchCV(KNeighborsClassifier(), grid_params, verbose = 1, cv=3, n_jobs = -1)

# %% [markdown]
# **GridSearchCV 설명:**
#
# 이 코드는 위에서 정의한 36개의 하이퍼파라미터 조합을 모두 시도하여 최적의 조합을 찾습니다.
#
# - **KNeighborsClassifier()**: KNN 분류 모델 객체
# - **grid_params**: 위에서 정의한 하이퍼파라미터 후보 딕셔너리
# - **verbose = 1**: 진행 상황을 출력 (0=조용히, 1=상세, 2=매우 상세)
# - **cv=3**: 3-fold 교차검증 (데이터를 3개로 나누어 각각 검증)
# - **n_jobs = -1**: 모든 CPU 코어를 사용하여 병렬 처리 (빠른 실행)
#
# **작동 방식:**
# 1. 36개 조합 × 3-fold = **총 108번의 학습/평가** 수행
# 2. 각 조합의 평균 성능 점수 계산
# 3. 가장 높은 성능을 보인 조합을 최적 파라미터로 선택
# 4. 결과는 `gs.best_params_`와 `gs.best_score_`로 확인 가능

# %%
# fit(): 정의된 모든 하이퍼파라미터 조합에 대해 교차 검증을 수행하고 최적의 조합을 찾음
# X_train: 학습용 입력 데이터 (특성 변수)
# y_train: 학습용 타겟 데이터 (이상치 레이블)
# g_res: GridSearchCV 결과 객체 (최적 파라미터와 성능 정보 포함)
g_res = gs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits

# %%
# 최적의 파라미터 조합으로 생성된 모델의 정확도
# best_score_: 교차 검증에서 얻은 최고 성능 점수 (정확도)
# 모든 하이퍼파라미터 조합 중 가장 좋은 성능을 보인 모델의 점수
g_res.best_score_
# Out:
# np.float64(0.9763652516589488)

# %%
# 최적의 파라미터 조합
# best_params_: 최고 성능을 낸 하이퍼파라미터 조합을 딕셔너리로 반환
# 예: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'minkowski'}
# 이 파라미터들을 사용하여 최종 모델을 구성
g_res.best_params_
# Out:
# {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}

# %% [markdown]
# **모델 생성**

# %%
# 값을 직접 입력 (GridSearchCV 결과를 바탕으로 최적 파라미터 설정)
# KNeighborsClassifier: K-최근접 이웃 분류기 객체 생성
# n_neighbors=5: 가장 가까운 5개의 이웃을 사용 (K=5)
# weights='distance': 거리 기반 가중치 사용 (가까운 이웃에 더 큰 영향)
# algorithm='brute': 브루트 포스 알고리즘 사용 (모든 점과의 거리 계산)
# metric='minkowski': 민코프스키 거리 측정 방법 사용
knn = KNeighborsClassifier(n_neighbors = 5, weights = 'distance',algorithm = 'brute',metric = 'minkowski')
# fit(): 학습 데이터로 모델 학습
# X_train: 입력 특성, y_train: 타겟 레이블
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='brute', weights='distance')

# %%
# 모델 예측
# predict(): 학습된 모델을 사용하여 새로운 데이터에 대한 예측 수행
# KNN_train_pred: 학습 데이터에 대한 예측 결과 (과적합 확인용)
KNN_train_pred = knn.predict(X_train)
# KNN_test_pred: 테스트 데이터에 대한 예측 결과 (실제 성능 평가용)
# 각 샘플에 대해 0(정상) 또는 1(이상)로 예측
KNN_test_pred = knn.predict(X_test)

# %%
# train, test 정확도 확인
# accuracy_score(): 예측값과 실제값을 비교하여 정확도 계산
# (맞게 예측한 샘플 수) / (전체 샘플 수)
# Training set accuracy: 학습 데이터에 대한 정확도 (과적합 여부 확인)
print('Training set accuracy: ', metrics.accuracy_score(y_train, KNN_train_pred))
# Test set accuracy: 테스트 데이터에 대한 정확도 (실제 모델 성능)
# 테스트 정확도가 학습 정확도보다 낮으면 과적합 가능성
print('Test set accuracy: ',metrics.accuracy_score(y_test, KNN_test_pred))
# Out:
# Training set accuracy:  1.0
# Test set accuracy:  1.0

# %%
# Confusion matrix 출력 및 모델 성능 평가
# confusion_matrix(): 혼동 행렬 생성
# y_test: 실제 정답 레이블, KNN_test_pred: 모델 예측값
# 결과는 2x2 행렬: [[TN, FP], [FN, TP]]
# TN(True Negative): 정상을 정상으로 예측, FP(False Positive): 정상을 이상으로 예측
# FN(False Negative): 이상을 정상으로 예측, TP(True Positive): 이상을 이상으로 예측
con_mat = confusion_matrix(y_test, KNN_test_pred)

# heatmap(): 혼동 행렬을 히트맵으로 시각화
# pd.DataFrame(): 혼동 행렬을 데이터프레임으로 변환
# xticklabels, yticklabels: x축, y축 레이블 설정
# annot=True: 각 셀에 숫자 값 표시
# fmt="d": 정수 형식으로 표시
# linewidths=.5: 셀 간 경계선 두께
# cmap="YlGnBu": 색상 맵 설정 (노란색-초록색-파란색)
sns.heatmap(pd.DataFrame(con_mat, columns = ['Predicted', 'Actual']),
            xticklabels=['Normal [0]', 'Abnormal [1]'], 
            yticklabels=['Normal [0]', 'Abnormal [1]'], 
            annot=True, fmt="d", linewidths=.5, cmap="YlGnBu")
# y축 레이블: 실제 값 (Actual)
plt.ylabel('Actual')
# x축 레이블: 예측 값 (Predicted)
plt.xlabel('Predicted')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted')

# %% [markdown]
# **(2) 이상치 예측 시각화**

# %% [markdown]
# **모델 기반으로 이상치 정의**
# - 거리가 먼 것이 이상치일 확률 높음

# %%
# 모델에서 k-neighbors의 거리 및 인덱스 출력
# kneighbors(): 각 테스트 샘플에 대해 가장 가까운 k개의 이웃을 찾음
# distances: 각 샘플에서 k개 이웃까지의 거리 배열 (shape: [n_samples, k])
# indexes: 각 샘플의 k개 이웃 인덱스 배열 (shape: [n_samples, k])
distances, indexes = knn.kneighbors(X_test)
# 각 관측치의 k-거리에 대한 플롯 평균
# mean(axis=1): 각 샘플의 k개 이웃까지의 거리의 평균을 계산
# 이상치일수록 가장 가까운 이웃까지의 거리가 클 것으로 예상됨
plt.plot(distances.mean(axis =1))

# %%
# 컷오프 값을 시각적으로 결정 > 2 (이상치가 발생되는 거리의 기준)
# np.where(): 조건을 만족하는 인덱스를 찾는 함수
# distances.mean(axis=1) > 2: 평균 거리가 2보다 큰 샘플들을 찾음
# 이상치는 정상 데이터와 멀리 떨어져 있으므로 이웃까지의 평균 거리가 클 것
# 2는 임계값(threshold)으로, 시각적으로 결정한 값
outlier_index = np.where(distances.mean(axis = 1) > 2) 
# 이상치로 판단된 샘플의 인덱스 출력
outlier_index
# Out:
# (array([503, 505, 506, 508, 509, 511, 515, 516, 517, 519, 520, 521, 526,
#         528, 529, 531, 534, 535, 536, 538, 540, 542, 543, 544, 545, 546,
#         549]),)

# %%
# 이상값 필터링
# iloc: 정수 위치 기반 인덱싱
# outlier_index에 해당하는 행들을 추출하여 이상치 데이터만 선택
# KNN 기반 이상치 탐지 결과를 확인
outlier_values = df.iloc[outlier_index] 
# 이상치로 판단된 데이터 출력
outlier_values
# Out:
#      feature1   feature2  anomaly_indicator
# 3   -7.155193 -12.959039                  1
# 5    2.416706  18.846522                  1
# 6   12.370277  -8.044471                  1
# 8    3.059020  14.070178                  1
# 9  -24.553628  10.839973                  1
# 11  13.279177  16.327586                  1
# 15   4.539934  11.369519                  1
# 16 -15.162708   2.176385                  1
# 17 -16.086432  23.811541                  1
# 19   4.106947  -4.237170                  1
# 20  -8.096714   4.823241                  1
# 21  10.763650  26.712719                  1
# 26  19.807777  -9.173803                  1
# 28   9.620632  -3.117863                  1
# 29 -15.325713   8.931610                  1
# 31  12.764066   2.504539                  1
# 34  -3.055499  16.528238                  1
# 35   1.081270  22.162492                  1
# 36  19.651850  -5.468991                  1
# 38  23.673816 -10.239869                  1
# ...

# %% [markdown]
# **모델 결과 기반으로 정상, 이상 예측결과 시각화**

# %%
# 플롯 데이터 (전체 데이터 시각화)
# scatter(): 산점도 그래프 생성
# x=df['feature1'], y=df['feature2']: x축과 y축에 각 특성 설정
# c=df['anomaly_indicator']: 색상을 이상치 지표로 구분 (0=정상, 1=이상)
# cmap='rainbow': 무지개 색상 맵 사용
# s=65: 점의 크기 설정
# 전체 테스트 데이터의 분포와 실제 이상치 위치를 확인
plt.scatter(df['feature1'], df['feature2'], c=df['anomaly_indicator'], cmap='rainbow', s = 65)

# %% [markdown]
# **전체 데이터 분포 시각화**
#
# 이 그래프는 test 데이터셋의 모든 데이터 포인트를 2차원 공간에 표시합니다.
#
# **그래프 해석:**
# - **X축 (feature1)**: 첫 번째 특성 값 (-25 ~ 25)
# - **Y축 (feature2)**: 두 번째 특성 값 (-15 ~ 25)
# - **색상 (cmap='rainbow')**: `anomaly_indicator` 값에 따라 색상이 달라집니다
#   - **보라색/파란색**: 정상 데이터 (anomaly_indicator=0) → 3개의 밀집된 클러스터 형성
#   - **빨간색/주황색**: 이상 데이터 (anomaly_indicator=1) → 넓게 분산되어 있음
#
# **주요 특징:**
# - 정상 데이터는 3개의 뚜렷한 클러스터로 밀집되어 있습니다
# - 이상 데이터는 정상 클러스터에서 멀리 떨어진 곳에 넓게 퍼져 있습니다
# - 이는 `cluster_std=1`(정상)과 `cluster_std=10`(이상)의 차이를 시각적으로 보여줍니다

# %%
# 이상치 그래프 (KNN으로 탐지된 이상치만 시각화)
# KNN 알고리즘이 탐지한 이상치들을 시각화
# outlier_values: KNN 기반 이상치 탐지 결과
# 실제 이상치와 탐지된 이상치를 비교하여 모델 성능 확인
plt.scatter(outlier_values['feature1'], outlier_values['feature2'], c=outlier_values['anomaly_indicator'], cmap='rainbow')

# %% [markdown]
# **KNN 모델이 탐지한 이상치만 표시**
#
# 이 그래프는 KNN 모델이 이상치로 판단한 데이터 포인트들만 표시합니다.
#
# **그래프 해석:**
# - **X축, Y축**: feature1과 feature2 (동일)
# - **표시된 점들**: `outlier_index`에 해당하는 데이터만 표시
# - **색상**: 이상치로 판단된 데이터들의 실제 레이블에 따라 색상이 결정됩니다
#
# **주요 특징:**
# - KNN 모델이 평균 거리 > 2인 데이터를 이상치로 탐지했습니다
# - 탐지된 이상치들은 정상 데이터 클러스터에서 멀리 떨어진 위치에 있습니다
# - 대부분의 빨간색 점(실제 이상 데이터)이 탐지되었음을 확인할 수 있습니다

# %%
# 이상 데이터 시각화 (전체 데이터와 탐지된 이상치를 함께 표시)
# 플롯 데이터 (전체 테스트 데이터)
# 실제 이상치 위치를 보여주는 전체 데이터 산점도
plt.scatter(df['feature1'], df['feature2'], c=df['anomaly_indicator'], cmap='rainbow', s = 65)
# 이상값 플롯 (KNN으로 탐지된 이상치)
# KNN 알고리즘이 탐지한 이상치를 같은 그래프에 겹쳐서 표시
# 실제 이상치와 탐지된 이상치의 일치 여부를 시각적으로 비교
plt.scatter(outlier_values['feature1'], outlier_values['feature2'], c=outlier_values['anomaly_indicator'], cmap='rainbow')

# %% [markdown]
# **전체 데이터와 탐지된 이상치 함께 시각화**
#
# 이 그래프는 전체 데이터 분포와 KNN 모델이 탐지한 이상치를 함께 보여줍니다.
#
# **그래프 해석:**
# - **작은 점들 (s=65)**: 전체 test 데이터셋의 모든 포인트
#   - 보라색/파란색: 정상 데이터
#   - 빨간색/주황색: 이상 데이터
# - **큰 점들**: KNN 모델이 이상치로 판단한 데이터 포인트들
#   - 모델이 탐지한 이상치들이 정상 클러스터에서 멀리 떨어진 위치에 있음을 확인
#
# **핵심 인사이트:**
# - KNN 모델이 정상 데이터 클러스터(보라색 밀집 영역)에서 멀리 떨어진 데이터들을 이상치로 잘 탐지했습니다
# - 거리 기반 이상 탐지의 원리: "주변에 가까운 이웃이 적으면 이상치"
# - 실제 이상 데이터(빨간색) 대부분이 모델에 의해 탐지되었음을 시각적으로 확인할 수 있습니다

# %% [markdown]
# ### **5-2. 클러스터링 기반 이상탐지 모델: K-Means**
# - 각 군집의 평균(mean)을 활용하여 K개의 군집으로 묶는 알고리즘
# - 알고리즘 단계
#
#   > ![nn](../img/3.png)
#
#
# ![nn](../img/4.png)

# %% [markdown]
# **(1) 모델 생성 및 학습**

# %% [markdown]
# **엘보우 포인트를 활용한 클러스터링 개수 정의**
# - 클러스터의 중심 간의 거리를 측정한 후 제곱하여 모든 클러스터에 대한 제곱 오차를 합산한 값
# - 즉, 각 객체마다 인접한 군집과의 거리를 최소화하는 값을 구하는 것
# - 뚝 떨어지는 값을 일반적으로 엘보우 포인트라고 함

# %% [markdown]
# **SSD (Sum of Squared Distances) 계산 코드 설명**
#
# 이 코드는 클러스터 개수를 2개부터 10개까지 변경하면서 각각의 SSD 값을 계산합니다.
#
#
# **SSD의 의미:**
# - SSD가 작을수록 → 클러스터 내부 응집도가 높음 (데이터들이 중심에 가까움)
# - SSD가 클수록 → 클러스터 내부 응집도가 낮음 (데이터들이 중심에서 멀리 떨어져 있음)
# - 클러스터 개수가 증가하면 일반적으로 SSD는 감소하지만, 어느 시점 이후로는 감소폭이 줄어듭니다

# %%
# Elbow Method: 최적의 클러스터 개수(k)를 찾기 위한 방법
# SSD(Sum of Squared Distances): 각 데이터점에서 자신이 속한 클러스터 중심까지의 거리의 제곱합
# 클러스터 개수가 증가할수록 SSD는 감소하지만, 감소율이 급격히 줄어드는 지점(엘보우)이 최적 k
ssd = []
# 클러스터 개수를 2에서 10까지 변경하며 각각의 SSD 계산
for n_clusters in range(2, 11):
    # KMeans: K-means 클러스터링 알고리즘
    # n_clusters: 클러스터 개수 (현재 반복에서의 k 값)
    # init='k-means++': 초기 중심점 선택 방법 (스마트 초기화로 수렴 속도 향상)
    # max_iter=200: 최대 반복 횟수
    # n_init=10: 서로 다른 초기값으로 10번 실행하여 가장 좋은 결과 선택
    # random_state=0: 재현 가능한 결과를 위한 시드값
    kmeans = KMeans(n_clusters=n_clusters, init='k-means++', max_iter=200, n_init=10, random_state=0)
    # 학습 데이터로 클러스터링 수행
    kmeans.fit(X_train)
    # inertia_: SSD 값 (클러스터 내 분산의 합)
    # inertia가 작을수록 클러스터가 더 응집되어 있음
    ssd.append(kmeans.inertia_)

# %% [markdown]
# **Elbow Method 그래프 그리기**
#
# 이 코드는 위에서 계산한 SSD 값을 그래프로 시각화합니다.
#
# **Elbow Method 원리:**
# - 그래프에서 SSD가 급격히 감소하다가 완만해지는 지점을 찾습니다
# - 이 지점이 "엘보우 포인트(Elbow Point)"로, 최적의 클러스터 개수입니다
# - 엘보우 포인트 이후로는 클러스터를 늘려도 응집도 개선 효과가 크지 않습니다
# - 이 예제에서는 클러스터 개수 3이 적절해 보입니다 (데이터 생성 시 centers=3을 사용했기 때문)

# %%
# Elbow Method 결과 시각화
# figure(figsize=(10, 6)): 그래프 크기 설정
plt.figure(figsize=(10, 6))
# plot(): 클러스터 개수에 따른 SSD 변화를 선 그래프로 표시
# range(2, 11): x축 값 (클러스터 개수 2~10)
# ssd: y축 값 (각 클러스터 개수에 대한 SSD 값)
# marker='o': 데이터 포인트를 원형 마커로 표시
plt.plot(range(2, 11), ssd, marker='o')
# 그래프 제목
plt.title('Elbow Method for Optimal k')
# x축 레이블: 클러스터 개수
plt.xlabel('Number of clusters')
# y축 레이블: SSD 값
plt.ylabel('Sum of Squared Distances (SSD)')
# xticks: x축 눈금 설정
plt.xticks(range(2, 11))
# grid: 격자 표시 (가독성 향상)
plt.grid()
# 그래프 출력
plt.show()

# %%
# 모델 fit (최적의 클러스터 개수로 K-means 모델 학습)
# KMeans: K-means 클러스터링 알고리즘 객체 생성
# n_clusters=3: 클러스터 개수를 3으로 설정 (Elbow Method 결과를 바탕으로 결정)
km = KMeans(n_clusters=3)
# fit(): 학습 데이터로 클러스터링 수행
# 클러스터 중심점을 찾고 각 데이터를 가장 가까운 클러스터에 할당
# model: 학습된 K-means 모델 (클러스터 중심점 정보 포함)
model = km.fit(X_train)

# %% [markdown]
# **(2) 이상치 예측 시각화**

# %% [markdown]
# **모델 결과 기반으로 정상, 이상 예측결과 시각화**

# %%
# 시각화를 위한 색상 리스트 정의
# 각 클러스터를 다른 색상으로 표시하기 위한 색상 팔레트
colors=["red","blue","green","orange"]

# %%
# test 데이터셋을 이용하여 모델 예측
# predict(): 테스트 데이터의 각 샘플을 가장 가까운 클러스터에 할당
# y_pred: 각 샘플이 속한 클러스터 번호 (0, 1, 2 등)
y_pred = model.predict(X_test)

# 결과 시각화
# figure(figsize=(8,6)): 그래프 크기 설정
plt.figure(figsize=(8,6))
# 각 클러스터별로 반복 (실제로는 한 번만 실행되지만 구조상 반복문 사용)
for i in range(np.max(y_pred)+1):
    # scatter(): 테스트 데이터를 산점도로 표시
    # c=df['anomaly_indicator']: 색상을 실제 이상치 여부로 구분
    # 실제 정상/이상 데이터 분포 확인
    plt.scatter(df['feature1'], df['feature2'], c=df['anomaly_indicator'], cmap='rainbow', s=40)
# cluster_centers_: 학습된 클러스터의 중심점 좌표
# [:,0], [:,1]: 각 중심점의 첫 번째, 두 번째 특성 값
# c="black", s=100: 중심점을 검은색 큰 점으로 표시
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], label='Centers', c="black", s=100)
# 그래프 제목
plt.title("K-Means Clustering of Customer Data",size=20)
# 범례 표시
plt.legend()
# 그래프 출력
plt.show()

# %% [markdown]
# **km_label은 각 데이터 포인트가 어느 클러스터(그룹)에 속하는지를 나타내는 번호입니다.**

# %%
# Outlier detection (이상치 탐지)
# 각 센터에서 데이터의 거리를 계산하는 함수 정의
# 이상치는 자신이 속한 클러스터의 중심에서 멀리 떨어진 데이터
def distance_from_center(income, score, y, label) :
    # center_income: 해당 클러스터 중심의 첫 번째 특성 값
    center_income = model.cluster_centers_[label, 0]
    # center_score: 해당 클러스터 중심의 두 번째 특성 값
    center_score = model.cluster_centers_[label, 1]
    # 유클리드 거리 계산: sqrt((x1-x2)^2 + (y1-y2)^2)
    dist = np.sqrt((income - center_income) ** 2 + (score - center_score))
    # 소수점 셋째 자리까지 반올림하여 반환
    return np.round(dist, 3)

# km_label: 각 샘플이 속한 클러스터 번호를 데이터프레임에 추가
df['km_label'] = y_pred
# km_distance: 각 샘플에서 자신이 속한 클러스터 중심까지의 거리를 계산하여 추가
# 거리가 클수록 이상치일 가능성이 높음
df['km_distance'] = distance_from_center(df.feature1, df.feature2, df.anomaly_indicator, df.km_label)

# 결과 확인 (처음 5개 행 출력)
df.head()
# Out:
#    feature1  feature2  anomaly_indicator  km_label  km_distance
# 0 -5.730354 -7.583286                  0         2        0.651
# 1  1.942992  1.918875                  0         1        3.368
# 2  6.829682  1.164871                  0         1        1.143
# 3 -2.901306  7.550771                  0         0          NaN
# 4  5.841093  1.565094                  0         1          NaN

# %%
# 군집에서 멀리 떨어진 데이터 확인 -> 내림차순
# sort_values('km_distance', ascending=False): 거리 기준으로 내림차순 정렬
# head(10): 상위 10개 선택 (가장 멀리 떨어진 10개 샘플)
# index: 해당 행의 인덱스 추출
# list(): 인덱스를 리스트로 변환
outlier_indexs = list(df.sort_values('km_distance', ascending=False).head(10).index)
# isin(): 인덱스가 outlier_indexs에 포함되는 행만 선택
# K-means 기반 이상치 탐지 결과 (클러스터 중심에서 가장 먼 10개)
outliers = df[df.index.isin(outlier_indexs)]
# 이상치로 판단된 데이터 출력
print(outliers)
# Out:
#      feature1   feature2  anomaly_indicator  km_label  km_distance
# 9   -7.504446  -6.854019                  0         2        0.527
# 17  -8.002349  -6.497700                  0         2        1.233
# 21  -2.300334   7.054616                  0         0          NaN
# 26   4.384902   3.477163                  0         1        1.514
# 29  -1.555196   9.665677                  0         0        1.272
# 36   3.817658   2.216857                  0         1        1.559
# 38  -6.929091  -6.205290                  0         2        0.722
# 42  -2.728870   9.371399                  0         0          NaN
# 45   6.284847   1.724134                  0         1        0.731
# 46   4.527551   1.752200                  0         1        0.561
# 9  -24.553628  10.839973                  1         0       21.850
# 17 -16.086432  23.811541                  1         0       13.879
# 21  10.763650  26.712719                  1         0       14.124
# ...

# %%
# outlier 시각화
# figure(figsize=(8, 6)): 그래프 크기 설정
plt.figure(figsize=(8, 6))
# 각 클러스터별로 데이터를 다른 색상으로 표시
for i in range(np.max(y_pred)+1) :
    # y_pred==i: i번 클러스터에 속한 데이터만 선택
    # scatter(): 각 클러스터의 데이터를 산점도로 표시
    # c=df[y_pred==i].anomaly_indicator: 색상을 실제 이상치 여부로 구분
    # alpha=0.5: 투명도 설정 (겹치는 점 확인 용이)
    plt.scatter(df[y_pred==i].feature1, df[y_pred==i].feature2,
               c = df[y_pred==i].anomaly_indicator, label=i, alpha=0.5)
# 이상치를 특별한 마커로 표시
# outliers.feature1, outliers.feature2: 이상치의 좌표
# c='darkred', marker='x': 진한 빨간색 X 마커로 표시
plt.scatter(outliers.feature1, outliers.feature2, outliers.anomaly_indicator, c='darkred', marker='x')
# 클러스터 중심점 표시
# cluster_centers_: 클러스터 중심 좌표
# c='pink', s=100: 분홍색 큰 점으로 표시
plt.scatter(model.cluster_centers_[:, 0], model.cluster_centers_[:, 1], 
           label='Centers', c='pink', s=100)
# 그래프 제목
plt.title('Outlier Detection with K-Means Clustering')
# 범례 표시
plt.legend()

# 텍스트 추가: 탐지된 이상치 개수 표시
# text(x, y, text): 지정된 위치에 텍스트 추가
# fontdict: 텍스트 스타일 설정 (빨간색, 크기 12)
plt.text(1.8, -2.6, f'predicted outliers : {len(outliers)}',fontdict={'color':'red', 'size':12})
# 그래프 출력
plt.show()

# %% [markdown]
# ### **5-3. 밀도기반 이상탐지 모델: Gaussian Density Estimation**
# - 관측 데이터를 바탕으로 데이터의 실제 분포를 하나의 가우시안 분포에 근사하여 확률적으로 분석하는 방법
#
# ![nn](../img/5.png)

# %% [markdown]
# **(1) 모델 생성 및 학습**

# %%
# gaussian 분포를 이용해 Outlier를 검출 모델 (GDE - Gaussian Distribution Estimation)
# EllipticEnvelope: 타원형 봉투를 사용한 이상치 탐지 모델
# 가우시안 분포를 가정하고, 정상 데이터의 공분산 행렬을 추정
# 정상 데이터 영역을 타원형으로 모델링하고, 그 밖의 데이터를 이상치로 판단
gde = EllipticEnvelope()
# 모델 fit
# fit(): 학습 데이터로 모델 학습
# 정상 데이터의 평균과 공분산 행렬을 추정하여 타원형 경계를 생성
gde.fit(X_train)
# Out:
# EllipticEnvelope()

# %%
# train data에 대한 예측 값(정상=1, 이상=-1)
# predict(): 각 샘플이 정상(1) 또는 이상(-1)인지 예측
# EllipticEnvelope는 기본적으로 정상=1, 이상=-1로 반환
GDE_train_pred = gde.predict(X_train) 

# test data에 대한 예측 값(정상=1, 이상=-1)
# 테스트 데이터에 대한 예측 수행
GDE_test_pred = gde.predict(X_test) 
# 데이터프레임으로 변환 (다음 단계에서 처리하기 위해)
GDE_test_pred = pd.DataFrame(GDE_test_pred)
# test data에 대한 예측 값(정상=0, 이상=1)로 변환
# 다른 모델들과 일관성을 위해 레이블 변환
# -1(이상) -> 1, 1(정상) -> 0으로 변경
# 주의: 이 변환은 혼란스러울 수 있음. 일반적으로는 정상=0, 이상=1을 사용
GDE_test_pred = GDE_test_pred.replace({-1: 1, 1: 0})

# %%
# Confusion matrix 출력 및 모델 성능 평가 (GDE 모델)
# confusion_matrix(): GDE 모델의 예측 결과와 실제 값을 비교한 혼동 행렬 생성
# y_test: 실제 정답 레이블 (정상=0, 이상=1)
# GDE_test_pred: GDE 모델의 예측값 (위에서 변환된 값)
con_mat = confusion_matrix(y_test, GDE_test_pred)

# heatmap(): 혼동 행렬을 히트맵으로 시각화
# pd.DataFrame(): 혼동 행렬을 데이터프레임으로 변환
# xticklabels, yticklabels: 축 레이블 설정
# annot=True: 각 셀에 숫자 값 표시
# fmt="d": 정수 형식으로 표시
# linewidths=.5: 셀 간 경계선 두께
# cmap="YlGnBu": 색상 맵 설정
sns.heatmap(pd.DataFrame(con_mat, columns = ['Predicted', 'Actual']),
            xticklabels=['Normal [0]', 'Abnormal [1]'], 
            yticklabels=['Normal [0]', 'Abnormal [1]'], 
            annot=True, fmt="d", linewidths=.5, cmap="YlGnBu")
# y축 레이블: 실제 값
plt.ylabel('Actual')
# x축 레이블: 예측 값
plt.xlabel('Predicted')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted')

# %% [markdown]
# ### **5-4. 밀도기반 이상탐지 모델: Mixture of Gaussian**
# - 하나가 아니라 다수의 가우시안 분포를 사용하는 gaussian density estimation
#
# ![nn](../img/6.png)

# %% [markdown]
# **BIC (Bayesian Information Criterion)를 이용한 하이퍼파라미터 최적화**
#
# BIC는 모델 선택을 위한 정보 기준(Information Criterion)으로, 모델의 **적합도**와 **복잡도**를 균형있게 고려합니다.
#
# **BIC 수식:**
#
# $${BIC} = -2ln(hat{L}) + kln(n)$$
#
# **각 항의 의미:**
#
# - **$\\hat{L}$**: 최대우도(maximum likelihood)에서의 우도값
#   - 모델이 데이터에 가장 잘 맞게 학습됐을 때의 likelihood
#   - 데이터에 얼마나 잘 맞는지를 나타냄
#
# - **$k$**: 모델의 추정 파라미터 개수
#   - 모델의 복잡도를 나타냄
#
# - **$n$**: 데이터 샘플 수
#
# **BIC 해석:**
#
# - **$-2ln(hat{L})$**: 데이터 적합도 항
#   - 모델이 데이터에 잘 맞을수록 **작아짐**
#   - 우도가 클수록(데이터에 잘 맞을수록) 이 값이 감소
#
# - **$kln(n)$**: 복잡도 벌점 항
#   - 파라미터가 많을수록(모델이 복잡할수록) **커짐**
#   - 과적합을 방지하기 위한 페널티
#
# **BIC 선택 기준:**
#
# - **BIC가 작을수록 좋은 모델**
# - "데이터에 잘 맞으면서도 과하게 복잡하지 않은" 모델을 선호
# - 적합도와 복잡도 사이의 최적 균형점을 찾음
#
# **실제 사용:**
#
# 아래 코드에서는 여러 하이퍼파라미터 조합(n_components, covariance_type)에 대해 BIC를 계산하고, **가장 작은 BIC 값을 가진 모델**을 최적 모델로 선택합니다.

# %% [markdown]
# **(1) 모델 생성 및 학습**

# %%
# Hyperparameter (하이퍼파라미터 최적화 - BIC 기준)
# BIC(Bayesian Information Criterion): 모델 선택 기준 (낮을수록 좋음)
# 복잡도와 적합도를 균형있게 고려하는 정보 기준
lowest_bic = np.inf  # 최소 BIC 값을 저장할 변수 (초기값: 무한대)
bic = []  # 모든 조합의 BIC 값을 저장할 리스트
# n_components_range: 가우시안 혼합 모델의 컴포넌트(클러스터) 개수 범위
n_components_range = range(1, 7)  # 1개부터 6개까지
# cv_types: 공분산 행렬의 타입
# "spherical": 구형 (각 컴포넌트가 동일한 분산)
# "tied": 공유된 공분산 행렬 (모든 컴포넌트가 같은 공분산)
# "diag": 대각선 공분산 행렬 (특성 간 독립 가정)
# "full": 완전한 공분산 행렬 (특성 간 상관관계 고려)
cv_types = ["spherical", "tied", "diag", "full"]
# 모든 공분산 타입과 컴포넌트 개수 조합에 대해 반복
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a Gaussian mixture with EM (기댓값 최대화 알고리즘으로 가우시안 혼합 모델 학습)
        # GaussianMixture: 가우시안 혼합 모델 객체 생성
        # n_components: 가우시안 분포의 개수 (혼합 모델의 컴포넌트 수)
        # covariance_type: 공분산 행렬의 타입
        gmm = GaussianMixture(
            n_components=n_components, covariance_type=cv_type
        )
        # fit(): 학습 데이터로 모델 학습 (EM 알고리즘 사용)
        gmm.fit(X_train)
        # bic(): Bayesian Information Criterion 계산
        # BIC는 모델의 복잡도(파라미터 수)와 적합도를 함께 고려
        bic.append(gmm.bic(X_train))
        # 현재 BIC가 지금까지의 최소값보다 작으면 최적 모델로 업데이트
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm = gmm  # 최적 모델 저장
# 최적 모델의 하이퍼파라미터 출력
print("covariance : ", best_gmm.covariance_type)
print("n_components : ", best_gmm.n_components)
# Out:
# covariance :  spherical
# n_components :  4

# %%
# 모델 fit (최적의 하이퍼파라미터로 선택된 모델을 다시 학습)
# best_gmm: BIC 기준으로 선택된 최적의 가우시안 혼합 모델
# fit(): 학습 데이터로 최종 모델 학습
# y_gmm: 학습된 모델 객체 
y_gmm = best_gmm.fit(X_train)

# %%
# test data에 대한 예측 값(정상=0, 이상=1)
# predict(): 각 샘플이 속한 가우시안 컴포넌트(클러스터)를 예측
# 반환값은 컴포넌트 번호 (0, 1, 2, ...)
MOG_test_pred = best_gmm.predict(X_test) 
# 데이터프레임으로 변환
MOG_test_pred = pd.DataFrame(MOG_test_pred)
# test data에 대한 예측 값(정상=0, 이상=1)로 변환
# 가우시안 혼합 모델은 클러스터 번호를 반환하므로, 이를 이상치 여부로 변환
# 0, 1, 2번 클러스터는 정상(0)으로, 3번 클러스터는 이상(1)으로 변환
# 주의: 이 변환은 데이터에 따라 달라질 수 있음 (일반적으로는 거리나 확률 기반으로 판단)
MOG_test_pred = MOG_test_pred.replace({0: 0, 1: 0, 2: 0, 3: 1})

# %%
# Confusion matrix 출력 및 모델 성능 평가 (MOG 모델)
# confusion_matrix(): MOG 모델의 예측 결과와 실제 값을 비교한 혼동 행렬 생성
# y_test: 실제 정답 레이블
# MOG_test_pred: MOG 모델의 예측값 (이상치 여부로 변환된 값)
con_mat = confusion_matrix(y_test, MOG_test_pred)

# heatmap(): 혼동 행렬을 히트맵으로 시각화
sns.heatmap(pd.DataFrame(con_mat, columns = ['Predicted', 'Actual']),
            xticklabels=['Normal [0]', 'Abnormal [1]'], 
            yticklabels=['Normal [0]', 'Abnormal [1]'], 
            annot=True, fmt="d", linewidths=.5, cmap="YlGnBu")
# y축 레이블: 실제 값
plt.ylabel('Actual')
# x축 레이블: 예측 값
plt.xlabel('Predicted')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted')

# %% [markdown]
# **(2) 이상치 예측 시각화**

# %% [markdown]
# **모델 기반으로 이상치 정의**
# -  log-likelihood 기반으로 이상치 정의
#    -> log-likelihood는 해당 값이 뽑힐 확률을 의미, 따라서 log-likelihood가 낮으면 뽑힐 확률이 적음을 의미하기 때문에 이상치를 의미함

# %%
# test 각 샘플의 log-likelihood 계산
# score_samples(): 각 샘플에 대한 로그 우도(log-likelihood) 계산
# 로그 우도는 데이터가 모델에 얼마나 잘 맞는지를 나타내는 지표
# 값이 클수록 정상 데이터일 가능성이 높고, 작을수록 이상치일 가능성이 높음
score = best_gmm.score_samples(X_test)

# score column에 저장
# 계산된 로그 우도 점수를 데이터프레임에 추가
# 이 점수를 기반으로 임계값을 설정하여 이상치를 판단할 수 있음
df['gmm_score'] = score

# %%
# threshold 설정(퍼센트) -> 테스트 데이터의 10%는 이상치로 정의됨
# percentile(): 주어진 퍼센타일 값 계산
# score의 10번째 퍼센타일 값을 임계값으로 설정
# 즉, 점수가 낮은 하위 10%를 이상치로 판단
# 이는 비지도 학습에서 일반적으로 사용하는 방법 (상위/하위 일정 비율을 이상치로 간주)
pct_threshold = np.percentile(score, 10)
# 계산된 임계값 출력 (소수점 둘째 자리까지)
print(f'The threshold of the score is {pct_threshold:.2f}')
# Out:
# The threshold of the score is -6.80

# %%
# 이상치 레이블링 (퍼센타일 기반)
# apply(): 각 행에 함수를 적용
# lambda x: 1 if x < pct_threshold else 0
#   - gmm_score가 임계값(pct_threshold)보다 작으면 이상치(1)
#   - 그렇지 않으면 정상(0)
# anomaly_gmm_pct: 퍼센타일 기반으로 판단한 이상치 여부
df['anomaly_gmm_pct'] = df['gmm_score'].apply(lambda x: 1 if x < pct_threshold else 0)

# %%
# 그래프 그리기 (로그 우도 점수 분포 시각화)
# figure(figsize=(12, 8)): 그래프 크기 설정
plt.figure(figsize=(12, 8))
# score 분포
# histplot(): 히스토그램으로 로그 우도 점수의 분포를 시각화
# bins=100: 히스토그램 구간을 100개로 설정 (세밀한 분포 확인)
# alpha=0.8: 투명도 설정
sns.histplot(df['gmm_score'], bins=100, alpha=0.8)
# Threshold 값(값 지정)
# axvline(): 수직선을 그어 임계값 위치 표시
# x=-6.8: 직접 지정한 임계값 (시각적으로 결정한 값)
# color='orange': 주황색으로 표시
plt.axvline(x=-6.8, color='orange')
# value_threshold: 직접 지정한 임계값 변수에 저장
value_threshold = -6.8
# 이상치 레이블링 (값 기반)
# 직접 지정한 임계값을 사용하여 이상치 판단
# anomaly_gmm_value: 값 기반으로 판단한 이상치 여부
df['anomaly_gmm_value'] = df['gmm_score'].apply(lambda x: 1 if x < value_threshold else 0)

# %% [markdown]
# **모델 결과 기반으로 정상, 이상 예측결과 시각화**

# %%
# 예측한 이상치와 실제 값 그래프 (비교 시각화)
# subplots(1,2): 1행 2열의 서브플롯 생성 (나란히 두 개의 그래프)
# sharey=True: y축을 공유 (같은 y축 범위 사용)
# figsize=(20,12): 전체 그래프 크기 설정
fig, (ax0, ax1)=plt.subplots(1,2, sharey=True, figsize=(20,12))

# 실제 (Ground Truth - 정답 레이블)
# set_title(): 서브플롯 제목 설정
ax0.set_title('Ground Truth')
# scatter(): 실제 이상치 여부를 색상으로 표시한 산점도
# c=df['anomaly_indicator']: 실제 정답 레이블로 색상 구분
# cmap='rainbow': 무지개 색상 맵 사용
ax0.scatter(df['feature1'], df['feature2'], c=df['anomaly_indicator'], cmap='rainbow')

# 예측 (GMM 모델의 예측 결과)
ax1.set_title('GMM Predict Anomalies Using Percentage')
# scatter(): GMM 모델이 퍼센타일 기반으로 예측한 이상치를 색상으로 표시
# c=df['anomaly_gmm_pct']: 퍼센타일 기반 예측 레이블로 색상 구분
# 실제 값과 예측 값을 비교하여 모델 성능을 시각적으로 확인
ax1.scatter(df['feature1'], df['feature2'], c=df['anomaly_gmm_pct'], cmap='rainbow')
